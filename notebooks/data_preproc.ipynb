# %% [markdown]
# # **Ideias** 🤔
#
# * Predição de desempenho futuro e análise de outliers (*O que fez alguns alunos serem um dos melhores que já passou na Passos?*)
# * Predição para recomendação de bolsas, intercambio, etc
# * Análise comparatória de 2020, 2021 e 2022
# * Análise de alunos (*de forma individual? 🤔*) ao longo dos anos (*Ex: temos dados do 'ALUNO 1' em 2020 e 2021, já em 2022 não temos dados... Seria talvez desistência?*)
# * Análise de alunos que estão indo bem Vs alunos que não estão indo bem. Tentar entender o porquê um aluno vai bem e outro não.
# * Tentar prever qual seria a “pedra” de um novo aluno com X pontuações de índices em uma nova entrada

# %% [markdown]
# # 1. Pré-Processamento

# %%
import pandas as pd

# %% [markdown]
# ## 1.1 Leitura do dataset bruto

# %%
df = pd.read_csv("data/PEDE_PASSOS_DATASET_FIAP.csv", sep=";")
df.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 1                           NaN  ALUNO-2              NaN          NaN
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020          INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não           7.883752                  B
# 1             NaN               NaN                NaN                NaN
# 2              3H               Não  7.856389666666666                  B
# 3              1D               Não           5.076252                  D
# 4              2M               Não           8.077085                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  ...  \
# 0   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
# 1        NaN                                                NaN  ...
# 2   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
# 3    Quartzo  Ponto a melhorar em 2021: Melhorar a sua entre...  ...
# 4   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
#
#    IPP_2022           REC_AVA_1_2022         REC_AVA_2_2022  \
# 0       NaN                      NaN                    NaN
# 1  5.625000  Mantido na Fase + Bolsa  Mantido na Fase atual
# 2       NaN                      NaN                    NaN
# 3  6.250000        Promovido de Fase  Mantido na Fase atual
# 4  6.458333    Mantido na Fase atual      Promovido de Fase
#
#           REC_AVA_3_2022 REC_AVA_4_2022 INDICADO_BOLSA_2022 PONTO_VIRADA_2022  \
# 0                    NaN            NaN                 NaN               NaN
# 1                    NaN            NaN                 Sim               Não
# 2                    NaN            NaN                 NaN               NaN
# 3      Promovido de Fase            NaN                 Não               Não
# 4  Mantido na Fase atual            NaN                 Não               Não
#
#    IPV_2022 IAN_2022      NIVEL_IDEAL_2022
# 0       NaN      NaN                   NaN
# 1  7.916665      5.0  Fase 2 (5º e 6º ano)
# 2       NaN      NaN                   NaN
# 3  8.055553      5.0  Fase 3 (7º e 8º ano)
# 4  7.833337      5.0  Fase 3 (7º e 8º ano)
#
# [5 rows x 69 columns]

# %%
df.columns
# Out:
# Index(['INSTITUICAO_ENSINO_ALUNO_2020', 'NOME', 'IDADE_ALUNO_2020',
#        'ANOS_PM_2020', 'FASE_TURMA_2020', 'PONTO_VIRADA_2020', 'INDE_2020',
#        'INDE_CONCEITO_2020', 'PEDRA_2020', 'DESTAQUE_IEG_2020',
#        'DESTAQUE_IDA_2020', 'DESTAQUE_IPV_2020', 'IAA_2020', 'IEG_2020',
#        'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020', 'FASE_2021',
#        'TURMA_2021', 'INSTITUICAO_ENSINO_ALUNO_2021',
#        'SINALIZADOR_INGRESSANTE_2021', 'PEDRA_2021', 'INDE_2021', 'IAA_2021',
#        'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'REC_EQUIPE_1_2021',
#        'REC_EQUIPE_2_2021', 'REC_EQUIPE_3_2021', 'REC_EQUIPE_4_2021',
#        'PONTO_VIRADA_2021', 'IPV_2021', 'IAN_2021', 'NIVEL_IDEAL_2021',
#        'DEFASAGEM_2021', 'FASE_2022', 'TURMA_2022', 'ANO_INGRESSO_2022',
#        'BOLSISTA_2022', 'INDE_2022', 'CG_2022', 'CF_2022', 'CT_2022',
#        'PEDRA_2022', 'DESTAQUE_IEG_2022', 'DESTAQUE_IDA_2022',
#        'DESTAQUE_IPV_2022', 'IAA_2022', 'IEG_2022', 'IPS_2022', 'IDA_2022',
#        'NOTA_PORT_2022', 'NOTA_MAT_2022', 'NOTA_ING_2022', 'QTD_AVAL_2022',
#        'IPP_2022', 'REC_AVA_1_2022', 'REC_AVA_2_2022', 'REC_AVA_3_2022',
#        'REC_AVA_4_2022', 'INDICADO_BOLSA_2022', 'PONTO_VIRADA_2022',
#        'IPV_2022', 'IAN_2022', 'NIVEL_IDEAL_2022'],
#       dtype='object')

# %%
cols_2022 = df.columns[
    df.columns.str.contains("NOME") | df.columns.str.contains("2022")
]
cols_2021 = df.columns[
    df.columns.str.contains("NOME") | df.columns.str.contains("2021")
]
cols_2020 = df.columns[
    df.columns.str.contains("NOME") | df.columns.str.contains("2020")
]

df_2022 = df[cols_2022].dropna(subset=["INDE_2022"])
df_2021 = df[cols_2021].dropna(subset=["INDE_2021"])
df_2020 = df[cols_2020].dropna(subset=["INDE_2020"])

print(df_2022.info())
print(df_2021.info())
print(df_2020.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 862 entries, 1 to 1348
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NOME                 862 non-null    object
#  1   FASE_2022            862 non-null    float64
#  2   TURMA_2022           862 non-null    object
#  3   ANO_INGRESSO_2022    862 non-null    float64
#  4   BOLSISTA_2022        862 non-null    object
#  5   INDE_2022            862 non-null    float64
#  6   CG_2022              862 non-null    float64
#  7   CF_2022              862 non-null    float64
#  8   CT_2022              862 non-null    float64
#  9   PEDRA_2022           862 non-null    object
#  10  DESTAQUE_IEG_2022    862 non-null    object
#  11  DESTAQUE_IDA_2022    862 non-null    object
#  12  DESTAQUE_IPV_2022    862 non-null    object
#  13  IAA_2022             862 non-null    float64
#  14  IEG_2022             862 non-null    float64
#  15  IPS_2022             862 non-null    float64
#  16  IDA_2022             862 non-null    float64
#  17  NOTA_PORT_2022       860 non-null    float64
#  18  NOTA_MAT_2022        860 non-null    float64
#  19  NOTA_ING_2022        285 non-null    float64
#  20  QTD_AVAL_2022        862 non-null    float64
#  21  IPP_2022             862 non-null    float64
#  22  REC_AVA_1_2022       862 non-null    object
#  23  REC_AVA_2_2022       862 non-null    object
#  24  REC_AVA_3_2022       626 non-null    object
#  25  REC_AVA_4_2022       285 non-null    object
#  26  INDICADO_BOLSA_2022  862 non-null    object
#  27  PONTO_VIRADA_2022    862 non-null    object
#  28  IPV_2022             862 non-null    float64
#  29  IAN_2022             862 non-null    float64
#  30  NIVEL_IDEAL_2022     862 non-null    object
# dtypes: float64(17), object(14)
# memory usage: 215.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 686 entries, 0 to 1347
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   NOME                           686 non-null    object
#  1   FASE_2021                      686 non-null    float64
#  2   TURMA_2021                     686 non-null    object
#  3   INSTITUICAO_ENSINO_ALUNO_2021  686 non-null    object
#  4   SINALIZADOR_INGRESSANTE_2021   686 non-null    object
#  5   PEDRA_2021                     686 non-null    object
#  6   INDE_2021                      686 non-null    object
#  7   IAA_2021                       686 non-null    float64
#  8   IEG_2021                       686 non-null    float64
#  9   IPS_2021                       686 non-null    float64
#  10  IDA_2021                       686 non-null    float64
#  11  IPP_2021                       686 non-null    float64
#  12  REC_EQUIPE_1_2021              686 non-null    object
#  13  REC_EQUIPE_2_2021              686 non-null    object
#  14  REC_EQUIPE_3_2021              686 non-null    object
#  15  REC_EQUIPE_4_2021              686 non-null    object
#  16  PONTO_VIRADA_2021              686 non-null    object
#  17  IPV_2021                       686 non-null    float64
#  18  IAN_2021                       686 non-null    float64
#  19  NIVEL_IDEAL_2021               686 non-null    object
#  20  DEFASAGEM_2021                 686 non-null    float64
# dtypes: float64(9), object(12)
# memory usage: 117.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 728 entries, 0 to 1347
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  728 non-null    object
#  1   NOME                           728 non-null    object
#  2   IDADE_ALUNO_2020               728 non-null    object
#  3   ANOS_PM_2020                   728 non-null    object
#  4   FASE_TURMA_2020                728 non-null    object
#  5   PONTO_VIRADA_2020              702 non-null    object
#  6   INDE_2020                      728 non-null    object
#  7   INDE_CONCEITO_2020             728 non-null    object
#  8   PEDRA_2020                     728 non-null    object
#  9   DESTAQUE_IEG_2020              728 non-null    object
#  10  DESTAQUE_IDA_2020              728 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       728 non-null    object
#  13  IEG_2020                       728 non-null    object
#  14  IPS_2020                       728 non-null    object
#  15  IDA_2020                       728 non-null    object
#  16  IPP_2020                       728 non-null    object
#  17  IPV_2020                       728 non-null    object
#  18  IAN_2020                       728 non-null    object
# dtypes: object(19)
# memory usage: 113.8+ KB
# None

# %%
df_2021[df_2021["FASE_2021"].isna()]
# Out:
# Empty DataFrame
# Columns: [NOME, FASE_2021, TURMA_2021, INSTITUICAO_ENSINO_ALUNO_2021, SINALIZADOR_INGRESSANTE_2021, PEDRA_2021, INDE_2021, IAA_2021, IEG_2021, IPS_2021, IDA_2021, IPP_2021, REC_EQUIPE_1_2021, REC_EQUIPE_2_2021, REC_EQUIPE_3_2021, REC_EQUIPE_4_2021, PONTO_VIRADA_2021, IPV_2021, IAN_2021, NIVEL_IDEAL_2021, DEFASAGEM_2021]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_2020.columns = df_2020.columns.str.replace("_2020", "").str.lower()
df_2021.columns = df_2021.columns.str.replace("_2021", "").str.lower()
df_2022.columns = df_2022.columns.str.replace("_2022", "").str.lower()

print(df_2020.info())
print(df_2021.info())
print(df_2022.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 728 entries, 0 to 1347
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   instituicao_ensino_aluno  728 non-null    object
#  1   nome                      728 non-null    object
#  2   idade_aluno               728 non-null    object
#  3   anos_pm                   728 non-null    object
#  4   fase_turma                728 non-null    object
#  5   ponto_virada              702 non-null    object
#  6   inde                      728 non-null    object
#  7   inde_conceito             728 non-null    object
#  8   pedra                     728 non-null    object
#  9   destaque_ieg              728 non-null    object
#  10  destaque_ida              728 non-null    object
#  11  destaque_ipv              703 non-null    object
#  12  iaa                       728 non-null    object
#  13  ieg                       728 non-null    object
#  14  ips                       728 non-null    object
#  15  ida                       728 non-null    object
#  16  ipp                       728 non-null    object
#  17  ipv                       728 non-null    object
#  18  ian                       728 non-null    object
# dtypes: object(19)
# memory usage: 113.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 686 entries, 0 to 1347
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nome                      686 non-null    object
#  1   fase                      686 non-null    float64
#  2   turma                     686 non-null    object
#  3   instituicao_ensino_aluno  686 non-null    object
#  4   sinalizador_ingressante   686 non-null    object
#  5   pedra                     686 non-null    object
#  6   inde                      686 non-null    object
#  7   iaa                       686 non-null    float64
#  8   ieg                       686 non-null    float64
#  9   ips                       686 non-null    float64
#  10  ida                       686 non-null    float64
#  11  ipp                       686 non-null    float64
#  12  rec_equipe_1              686 non-null    object
#  13  rec_equipe_2              686 non-null    object
#  14  rec_equipe_3              686 non-null    object
#  15  rec_equipe_4              686 non-null    object
#  16  ponto_virada              686 non-null    object
#  17  ipv                       686 non-null    float64
#  18  ian                       686 non-null    float64
#  19  nivel_ideal               686 non-null    object
#  20  defasagem                 686 non-null    float64
# dtypes: float64(9), object(12)
# memory usage: 117.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 862 entries, 1 to 1348
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nome            862 non-null    object
#  1   fase            862 non-null    float64
#  2   turma           862 non-null    object
#  3   ano_ingresso    862 non-null    float64
#  4   bolsista        862 non-null    object
#  5   inde            862 non-null    float64
#  6   cg              862 non-null    float64
#  7   cf              862 non-null    float64
#  8   ct              862 non-null    float64
#  9   pedra           862 non-null    object
#  10  destaque_ieg    862 non-null    object
#  11  destaque_ida    862 non-null    object
#  12  destaque_ipv    862 non-null    object
#  13  iaa             862 non-null    float64
#  14  ieg             862 non-null    float64
#  15  ips             862 non-null    float64
#  16  ida             862 non-null    float64
#  17  nota_port       860 non-null    float64
#  18  nota_mat        860 non-null    float64
#  19  nota_ing        285 non-null    float64
#  20  qtd_aval        862 non-null    float64
#  21  ipp             862 non-null    float64
#  22  rec_ava_1       862 non-null    object
#  23  rec_ava_2       862 non-null    object
#  24  rec_ava_3       626 non-null    object
#  25  rec_ava_4       285 non-null    object
#  26  indicado_bolsa  862 non-null    object
#  27  ponto_virada    862 non-null    object
#  28  ipv             862 non-null    float64
#  29  ian             862 non-null    float64
#  30  nivel_ideal     862 non-null    object
# dtypes: float64(17), object(14)
# memory usage: 215.5+ KB
# None

# %%
df_2022[df_2022["nome"] == "ALUNO-727"]
# Out:
#           nome  fase turma  ano_ingresso bolsista      inde     cg     cf  \
# 726  ALUNO-727   0.0     N        2022.0      Não  5.702446  760.0  183.0
#
#       ct    pedra  ...    ipp              rec_ava_1              rec_ava_2  \
# 726  8.0  Quartzo  ...  5.625  Mantido na Fase atual  Mantido na Fase atual
#
#      rec_ava_3  rec_ava_4  indicado_bolsa  ponto_virada       ipv  ian  \
# 726        NaN        NaN             Não           Não  7.083325  5.0
#
#               nivel_ideal
# 726  Fase 2 (5º e 6º ano)
#
# [1 rows x 31 columns]

# %% [markdown]
# ### Dados de sexo e raça retirados da base bruta

# %%
df_tb_aluno = pd.read_csv("data/TBAluno.csv", sep=",")
df_tb_aluno.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 56 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   IdAluno                                 2238 non-null   int64
#  1   NomeAluno                               2238 non-null   object
#  2   NomeAbreviado                           0 non-null      float64
#  3   IdUnidade                               2237 non-null   float64
#  4   Sexo                                    2237 non-null   object
#  5   EstadoCivil                             2237 non-null   float64
#  6   DataNascimento                          2238 non-null   object
#  7   IdPai                                   800 non-null    float64
#  8   IdMae                                   1218 non-null   object
#  9   IdResponsavel                           2237 non-null   float64
#  10  IdTipoResponsavel                       2238 non-null   int64
#  11  Naturalidade                            1 non-null      object
#  12  Nacionalidade                           2 non-null      object
#  13  TipoSangue                              0 non-null      float64
#  14  PlanoSaude                              0 non-null      float64
#  15  Alergia                                 0 non-null      float64
#  16  Medicamento                             0 non-null      float64
#  17  IdEstabelecimentoEnsinoAnterior         0 non-null      float64
#  18  IdReligiao                              0 non-null      float64
#  19  AnoConclusao                            0 non-null      float64
#  20  CorRaca                                 2237 non-null   object
#  21  StDeficienciaCegueira                   2237 non-null   object
#  22  StDeficienciaBaixaVisao                 2237 non-null   object
#  23  StDeficienciaSurdez                     2238 non-null   bool
#  24  StDeficienciaAuditiva                   2238 non-null   bool
#  25  StDeficienciaFisica                     2238 non-null   bool
#  26  StDeficienciaSurdoCegueira              2238 non-null   bool
#  27  StDeficienciaMultipla                   2238 non-null   bool
#  28  StDeficienciaMental                     2238 non-null   bool
#  29  _IdResponsavel_CadastroVinculado        1 non-null      object
#  30  StFalecido                              2237 non-null   object
#  31  EnsinoMedio_IdEstabelecimentoEnsino     0 non-null      float64
#  32  EnsinoMedio_AnoConclusao                1 non-null      object
#  33  StDeficienciaAutismoInfantil            2237 non-null   object
#  34  StDeficienciaSindromeAsperger           2237 non-null   object
#  35  StDeficienciaSindromeRett               2238 non-null   bool
#  36  StDeficienciaTrastornoDesintegrativo    2238 non-null   bool
#  37  StDeficienciaAltasHabilidades           2238 non-null   bool
#  38  NomeCivil                               0 non-null      float64
#  39  StAppComunicacao_Sincronizado           2237 non-null   object
#  40  IdTipoResponsavelPai                    608 non-null    object
#  41  IdTipoResponsavelMae                    480 non-null    float64
#  42  StRecursoAuxilioLedor                   2237 non-null   object
#  43  StRecursoAuxilioTranscricao             2237 non-null   object
#  44  StRecursoGuiaInterprete                 2238 non-null   bool
#  45  StRecursoTradutorInterpreteDeLibras     2238 non-null   bool
#  46  StRecursoLeituraLabial                  2238 non-null   bool
#  47  StRecursoMaterialDidaticoProvaBraille   2238 non-null   bool
#  48  StRecursoProvaAmpliada                  2238 non-null   bool
#  49  StRecursoProvaSuperampliada             2238 non-null   bool
#  50  StRecursoCdComAudio                     2238 non-null   bool
#  51  StRecursoLinguaPortuguesaSegundaLingua  2238 non-null   bool
#  52  StRecursoProvaEmVideo                   2238 non-null   bool
#  53  StPermiteUsoImagem                      2238 non-null   bool
#  54  StEstrangeiro                           2238 non-null   bool
#  55  Unnamed: 55                             1 non-null      object
# dtypes: bool(20), float64(15), int64(2), object(19)
# memory usage: 673.3+ KB

# %%
df_tb_aluno["NomeAluno"].unique()
# Out:
# array(['Aluno 1', 'Aluno 2', 'Aluno 3', ..., 'Aluno 2236', 'Aluno 2237',
#        'Aluno 2238'], dtype=object)

# %%
df_tb_aluno["NomeAluno"] = df_tb_aluno["NomeAluno"].str.upper().str.replace(" ", "-")
df_tb_aluno.head()
# Out:
#    IdAluno NomeAluno  NomeAbreviado  IdUnidade Sexo  EstadoCivil  \
# 0        3   ALUNO-1            NaN        1.0    F          5.0
# 1        4   ALUNO-2            NaN        1.0    F          5.0
# 2        5   ALUNO-3            NaN        1.0    F          5.0
# 3        6   ALUNO-4            NaN        1.0    M          5.0
# 4        7   ALUNO-5            NaN        1.0    M          5.0
#
#         DataNascimento  IdPai IdMae  IdResponsavel  ...  \
# 0  2005-03-29 03:00:00    NaN     5            5.0  ...
# 1  2004-11-04 02:00:00    6.0   NaN            6.0  ...
# 2  2002-01-25 02:00:00    NaN   NaN            7.0  ...
# 3  2002-10-07 03:00:00    NaN     8            8.0  ...
# 4  2002-12-23 02:00:00    NaN     9            9.0  ...
#
#    StRecursoLeituraLabial StRecursoMaterialDidaticoProvaBraille  \
# 0                   False                                 False
# 1                   False                                 False
# 2                   False                                 False
# 3                   False                                 False
# 4                   False                                 False
#
#   StRecursoProvaAmpliada  StRecursoProvaSuperampliada  StRecursoCdComAudio  \
# 0                  False                        False                False
# 1                  False                        False                False
# 2                  False                        False                False
# 3                  False                        False                False
# 4                  False                        False                False
#
#    StRecursoLinguaPortuguesaSegundaLingua  StRecursoProvaEmVideo  \
# 0                                   False                  False
# 1                                   False                  False
# 2                                   False                  False
# 3                                   False                  False
# 4                                   False                  False
#
#    StPermiteUsoImagem  StEstrangeiro  Unnamed: 55
# 0               False          False          NaN
# 1               False          False          NaN
# 2               False          False          NaN
# 3               False          False          NaN
# 4               False          False          NaN
#
# [5 rows x 56 columns]

# %%
df_tb_aluno = (
    df_tb_aluno[["NomeAluno", "Sexo", "CorRaca"]]
    .rename(columns={"NomeAluno": "nome"})
    .set_index("nome")
)
df_tb_aluno.columns = df_tb_aluno.columns.str.lower()
df_tb_aluno.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2238 entries, ALUNO-1 to ALUNO-2238
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sexo     2237 non-null   object
#  1   corraca  2237 non-null   object
# dtypes: object(2)
# memory usage: 52.5+ KB

# %%
df_tb_aluno.dropna(inplace=True)
# ano_aluno = df_tb_aluno['datanascimento'].apply(lambda x:  str(x).split("-")[0]).astype(int)
# df_tb_aluno['ano_nasc'] =  ano_aluno

# %% [markdown]
# ### join dos dados de sexo e raça nos datasets de 2020, 2021 e 2022

# %%
df_2020 = df_2020.set_index("nome").join(df_tb_aluno)
df_2021 = df_2021.set_index("nome").join(df_tb_aluno)
df_2022 = df_2022.set_index("nome").join(df_tb_aluno)

print(df_2020.info())
print(df_2021.info())
print(df_2022.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 728 entries, ALUNO-1 to ALUNO-1348
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   instituicao_ensino_aluno  728 non-null    object
#  1   idade_aluno               728 non-null    object
#  2   anos_pm                   728 non-null    object
#  3   fase_turma                728 non-null    object
#  4   ponto_virada              702 non-null    object
#  5   inde                      728 non-null    object
#  6   inde_conceito             728 non-null    object
#  7   pedra                     728 non-null    object
#  8   destaque_ieg              728 non-null    object
#  9   destaque_ida              728 non-null    object
#  10  destaque_ipv              703 non-null    object
#  11  iaa                       728 non-null    object
#  12  ieg                       728 non-null    object
#  13  ips                       728 non-null    object
#  14  ida                       728 non-null    object
#  15  ipp                       728 non-null    object
#  16  ipv                       728 non-null    object
#  17  ian                       728 non-null    object
#  18  sexo                      727 non-null    object
#  19  corraca                   727 non-null    object
# dtypes: object(20)
# memory usage: 135.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 686 entries, ALUNO-1 to ALUNO-1348
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   fase                      686 non-null    float64
#  1   turma                     686 non-null    object
#  2   instituicao_ensino_aluno  686 non-null    object
#  3   sinalizador_ingressante   686 non-null    object
#  4   pedra                     686 non-null    object
#  5   inde                      686 non-null    object
#  6   iaa                       686 non-null    float64
#  7   ieg                       686 non-null    float64
#  8   ips                       686 non-null    float64
#  9   ida                       686 non-null    float64
#  10  ipp                       686 non-null    float64
#  11  rec_equipe_1              686 non-null    object
#  12  rec_equipe_2              686 non-null    object
#  13  rec_equipe_3              686 non-null    object
#  14  rec_equipe_4              686 non-null    object
#  15  ponto_virada              686 non-null    object
#  16  ipv                       686 non-null    float64
#  17  ian                       686 non-null    float64
#  18  nivel_ideal               686 non-null    object
#  19  defasagem                 686 non-null    float64
#  20  sexo                      685 non-null    object
#  21  corraca                   685 non-null    object
# dtypes: float64(9), object(13)
# memory usage: 139.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 862 entries, ALUNO-2 to ALUNO-1349
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fase            862 non-null    float64
#  1   turma           862 non-null    object
#  2   ano_ingresso    862 non-null    float64
#  3   bolsista        862 non-null    object
#  4   inde            862 non-null    float64
#  5   cg              862 non-null    float64
#  6   cf              862 non-null    float64
#  7   ct              862 non-null    float64
#  8   pedra           862 non-null    object
#  9   destaque_ieg    862 non-null    object
#  10  destaque_ida    862 non-null    object
#  11  destaque_ipv    862 non-null    object
#  12  iaa             862 non-null    float64
#  13  ieg             862 non-null    float64
#  14  ips             862 non-null    float64
#  15  ida             862 non-null    float64
#  16  nota_port       860 non-null    float64
#  17  nota_mat        860 non-null    float64
#  18  nota_ing        285 non-null    float64
#  19  qtd_aval        862 non-null    float64
#  20  ipp             862 non-null    float64
#  21  rec_ava_1       862 non-null    object
#  22  rec_ava_2       862 non-null    object
#  23  rec_ava_3       626 non-null    object
#  24  rec_ava_4       285 non-null    object
#  25  indicado_bolsa  862 non-null    object
#  26  ponto_virada    862 non-null    object
#  27  ipv             862 non-null    float64
#  28  ian             862 non-null    float64
#  29  nivel_ideal     862 non-null    object
#  30  sexo            861 non-null    object
#  31  corraca         861 non-null    object
# dtypes: float64(17), object(15)
# memory usage: 254.5+ KB
# None

# %%
df_tb_aluno.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2237 entries, ALUNO-1 to ALUNO-2238
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sexo     2237 non-null   object
#  1   corraca  2237 non-null   object
# dtypes: object(2)
# memory usage: 117.0+ KB

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 728 entries, ALUNO-1 to ALUNO-1348
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   instituicao_ensino_aluno  728 non-null    object
#  1   idade_aluno               728 non-null    object
#  2   anos_pm                   728 non-null    object
#  3   fase_turma                728 non-null    object
#  4   ponto_virada              702 non-null    object
#  5   inde                      728 non-null    object
#  6   inde_conceito             728 non-null    object
#  7   pedra                     728 non-null    object
#  8   destaque_ieg              728 non-null    object
#  9   destaque_ida              728 non-null    object
#  10  destaque_ipv              703 non-null    object
#  11  iaa                       728 non-null    object
#  12  ieg                       728 non-null    object
#  13  ips                       728 non-null    object
#  14  ida                       728 non-null    object
#  15  ipp                       728 non-null    object
#  16  ipv                       728 non-null    object
#  17  ian                       728 non-null    object
#  18  sexo                      727 non-null    object
#  19  corraca                   727 non-null    object
# dtypes: object(20)
# memory usage: 135.6+ KB

# %%
import re

# exclui dados inválidos
df_2020["fase"] = df_2020["fase_turma"].str.extract(r"(\d+)")
df_2020 = df_2020[df_2020["fase_turma"] != "D207"]
# exclui alunos da fase universitária fase 8
df_2020 = df_2020[df_2020["fase"] != "8"]

# %%
# escreve em arquivo
df_2020.to_csv("data/df_2020.csv", index=False)
df_2021.to_csv("data/df_2021.csv", index=False)
df_2022.to_csv("data/df_2022.csv", index=False)

# %% [markdown]
# ## 1.2 Limpeza de dados e construção do dataset para análise

# %%
import numpy as np

import category_encoders as ce

# %%
print(df_2020.columns)
print(df_2021.columns)
print(df_2022.columns)
# Out:
# Index(['instituicao_ensino_aluno', 'idade_aluno', 'anos_pm', 'fase_turma',
#        'ponto_virada', 'inde', 'inde_conceito', 'pedra', 'destaque_ieg',
#        'destaque_ida', 'destaque_ipv', 'iaa', 'ieg', 'ips', 'ida', 'ipp',
#        'ipv', 'ian', 'sexo', 'corraca', 'fase'],
#       dtype='object')
# Index(['fase', 'turma', 'instituicao_ensino_aluno', 'sinalizador_ingressante',
#        'pedra', 'inde', 'iaa', 'ieg', 'ips', 'ida', 'ipp', 'rec_equipe_1',
#        'rec_equipe_2', 'rec_equipe_3', 'rec_equipe_4', 'ponto_virada', 'ipv',
#        'ian', 'nivel_ideal', 'defasagem', 'sexo', 'corraca'],
#       dtype='object')
# Index(['fase', 'turma', 'ano_ingresso', 'bolsista', 'inde', 'cg', 'cf', 'ct',
#        'pedra', 'destaque_ieg', 'destaque_ida', 'destaque_ipv', 'iaa', 'ieg',
#        'ips', 'ida', 'nota_port', 'nota_mat', 'nota_ing', 'qtd_aval', 'ipp',
#        'rec_ava_1', 'rec_ava_2', 'rec_ava_3', 'rec_ava_4', 'indicado_bolsa',
#        'ponto_virada', 'ipv', 'ian', 'nivel_ideal', 'sexo', 'corraca'],
#       dtype='object')

# %% [markdown]
# ### Padroniza dados da coluna 'instituicao_ensino_aluno'
#
# Transforma os dados das colunas 'instituicao_ensino_aluno' e 'bolsista' para que fiquem com o mesmo nome e tipo de resposta:
# - 0 - Não bolsista (escola pública)
# - 1 - Bolsista (escola particular)

# %%
print(df_2020["instituicao_ensino_aluno"].unique())
print(df_2021["instituicao_ensino_aluno"].unique())
print(df_2022["bolsista"].unique())
# Out:
# ['Escola Pública' 'Rede Decisão/União' 'Einstein' 'Escola João Paulo II']
# ['Rede Decisão' 'Escola Pública' 'Escola JP II']
# ['Não' 'Sim']

# %%
print(df_2020["instituicao_ensino_aluno"].isnull().sum())
print(df_2021["instituicao_ensino_aluno"].isnull().sum())
print(df_2022["bolsista"].isnull().sum())
# Out:
# 0
# 0
# 0

# %%
def set_bolsista(x):
    if x == "Escola Pública":
        return 0
    else:
        return 1


df_2020["bolsista_encoded"] = df_2020["instituicao_ensino_aluno"].apply(set_bolsista)
df_2021["bolsista_encoded"] = df_2021["instituicao_ensino_aluno"].apply(set_bolsista)
df_2022["bolsista_encoded"] = df_2022["bolsista"].apply(
    lambda x: 0 if str(x) == "Não" else 1
)

print(df_2020["bolsista_encoded"].value_counts())
print(df_2021["bolsista_encoded"].value_counts())
print(df_2022["bolsista_encoded"].value_counts())
# Out:
# bolsista_encoded
# 0    598
# 1    105
# Name: count, dtype: int64
# bolsista_encoded
# 0    557
# 1    129
# Name: count, dtype: int64
# bolsista_encoded
# 0    754
# 1    108
# Name: count, dtype: int64

# %% [markdown]
# ### Padroniza os dados da coluna 'fase'
#
# Padroniza os dados da coluna 'fase' para que fiquem com o mesmo nome e tipo de resposta:
# - 0 - Fase 0 (ALFA)
# - 1 - Fase 1
# - 2 - Fase 2
# - 3 - Fase 3
# - 4 - Fase 4
# - 5 - Fase 5
# - 6 - Fase 6
# - 7 - Fase 7

# %%
print(df_2020["fase"].unique())
print(df_2021["fase"].unique())
print(df_2022["fase"].unique())
# Out:
# ['2' '3' '1' '4' '0' '7' '5' '6']
# [2. 3. 5. 1. 0. 4. 7. 6.]
# [0. 2. 1. 5. 4. 3. 7. 6.]

# %%
df_2020["fase"] = df_2020["fase"].astype(int)
df_2021["fase"] = df_2021["fase"].astype(int)
df_2022["fase"] = df_2022["fase"].astype(int)

print(df_2020["fase"].unique())
print(df_2021["fase"].unique())
print(df_2022["fase"].unique())
# Out:
# [2 3 1 4 0 7 5 6]
# [2 3 5 1 0 4 7 6]
# [0 2 1 5 4 3 7 6]

# %% [markdown]
# ### Padroniza os dados da coluna 'ponto_virada'
#
# Padroniza os dados da coluna 'ponto_virada' para que fiquem com o mesmo nome e tipo de resposta:
# - 0 - Não
# - 1 - Sim

# %%
print(df_2020["ponto_virada"].unique())
print(df_2021["ponto_virada"].unique())
print(df_2022["ponto_virada"].unique())
# Out:
# ['Não' 'Sim' nan]
# ['Não' 'Sim' '#NULO!']
# ['Não' 'Sim']

# %%
print(df_2020["ponto_virada"].isnull().sum())
print(df_2021["ponto_virada"].isnull().sum())
print(df_2022["ponto_virada"].isnull().sum())
# Out:
# 2
# 0
# 0

# %%
def set_ponto_virada(x):
    if x == "Não":
        return 0
    elif x != np.nan or x != "#NULO!":
        return 1
    else:
        return np.nan


df_2020["ponto_virada_encoded"] = df_2020["ponto_virada"].apply(set_ponto_virada)
df_2021["ponto_virada_encoded"] = df_2021["ponto_virada"].apply(set_ponto_virada)
df_2022["ponto_virada_encoded"] = df_2022["ponto_virada"].apply(set_ponto_virada)

print(df_2020["ponto_virada_encoded"].unique())
print(df_2021["ponto_virada_encoded"].unique())
print(df_2022["ponto_virada_encoded"].unique())
# Out:
# [0 1]
# [0 1]
# [0 1]

# %% [markdown]
# ### Padroniza os dados da coluna 'pedra'
#
# Padroniza os dados da coluna 'pedra' e faz o encodingpara que fiquem com o mesmo nome e tipo de resposta

# %%
print(df_2020["pedra"].unique())
print(df_2021["pedra"].unique())
print(df_2022["pedra"].unique())

print(df_2020["pedra"].isnull().sum())
print(df_2021["pedra"].isnull().sum())
print(df_2022["pedra"].isnull().sum())
# Out:
# ['Ametista' 'Quartzo' 'Topázio' 'Ágata']
# ['Ametista' 'Topázio' 'Quartzo' 'Ágata' '#NULO!']
# ['Ametista' 'Quartzo' 'Topázio' 'Ágata']
# 0
# 0
# 0

# %%
df_2021[df_2021["pedra"] == "#NULO!"]
# Out:
#            fase turma instituicao_ensino_aluno sinalizador_ingressante  \
# nome
# ALUNO-71      0     J           Escola Pública                Veterano
# ALUNO-506     0     J           Escola Pública                Veterano
#
#             pedra    inde  iaa  ieg  ips  ida  ...  rec_equipe_4 ponto_virada  \
# nome                                           ...
# ALUNO-71   #NULO!  #NULO!  7.4  0.0  5.0  3.6  ...  Não avaliado       #NULO!
# ALUNO-506  #NULO!  #NULO!  7.4  0.0  5.0  4.1  ...  Não avaliado       #NULO!
#
#            ipv   ian            nivel_ideal defasagem  sexo  corraca  \
# nome
# ALUNO-71   0.0   5.0  Nível 2 (5o e 6o ano)      -2.0     F        P
# ALUNO-506  0.0  10.0    ALFA  (2o e 3o ano)       0.0     M        B
#
#           bolsista_encoded  ponto_virada_encoded
# nome
# ALUNO-71                 0                     1
# ALUNO-506                0                     1
#
# [2 rows x 24 columns]

# %%
ordinal_encoder = ce.OrdinalEncoder(
    handle_missing="ignore",
    handle_unknown="ignore",
    mapping=[
        {
            "col": "pedra",
            "mapping": {"Topázio": 4, "Ametista": 3, "Ágata": 2, "Quartzo": 1},
        },
    ],
)

df_2020["pedra_encoded"] = ordinal_encoder.fit_transform(df_2020[["pedra"]])
df_2021["pedra_encoded"] = ordinal_encoder.fit_transform(df_2021[["pedra"]])
df_2022["pedra_encoded"] = ordinal_encoder.fit_transform(df_2022[["pedra"]])

print(df_2020["pedra_encoded"].unique())
print(df_2021["pedra_encoded"].unique())
print(df_2022["pedra_encoded"].unique())
# Out:
# [3 1 4 2]
# [ 3.  4.  1.  2. nan]
# [3 1 4 2]

# %%
df_2021[df_2021["pedra_encoded"].isna()][
    ["iaa", "ieg", "ips", "ida", "ipp", "ipv", "ian"]
]
# pela fórmula do cálculo do inde:
# Out:
#            iaa  ieg  ips  ida  ipp  ipv   ian
# nome
# ALUNO-71   7.4  0.0  5.0  3.6  0.0  0.0   5.0
# ALUNO-506  7.4  0.0  5.0  4.1  0.0  0.0  10.0

# %%
df_2021["inde"].head()
# Out:
# nome
# ALUNO-1     7.319
# ALUNO-3     7.021
# ALUNO-5     7.399
# ALUNO-8     8.269
# ALUNO-11    8.990
# Name: inde, dtype: object

# %%
def calc_inde(x):
    if x["inde"] == "#NULO!":
        return (
            (x["iaa"] * 0.10)
            + (x["ieg"] * 0.20)
            + (x["ips"] * 0.10)
            + (x["ida"] * 0.20)
            + (x["ipp"] * 0.10)
            + (x["ipv"] * 0.20)
            + (x["ian"] * 0.10)
        )
    else:
        return x["inde"]


# apply if not null
inde = df_2021.apply(calc_inde, axis=1)
df_2021["inde"] = inde

# %%
# segundo a PEDE 2021, Quartzo = 2.4 a 5.5
df_2021[df_2021["pedra_encoded"].isna()]
# Out:
#            fase turma instituicao_ensino_aluno sinalizador_ingressante  \
# nome
# ALUNO-71      0     J           Escola Pública                Veterano
# ALUNO-506     0     J           Escola Pública                Veterano
#
#             pedra  inde  iaa  ieg  ips  ida  ...  ponto_virada  ipv   ian  \
# nome                                         ...
# ALUNO-71   #NULO!  2.46  7.4  0.0  5.0  3.6  ...        #NULO!  0.0   5.0
# ALUNO-506  #NULO!  3.06  7.4  0.0  5.0  4.1  ...        #NULO!  0.0  10.0
#
#                      nivel_ideal defasagem sexo  corraca  bolsista_encoded  \
# nome
# ALUNO-71   Nível 2 (5o e 6o ano)      -2.0    F        P                 0
# ALUNO-506    ALFA  (2o e 3o ano)       0.0    M        B                 0
#
#           ponto_virada_encoded  pedra_encoded
# nome
# ALUNO-71                     1            NaN
# ALUNO-506                    1            NaN
#
# [2 rows x 25 columns]

# %%
df_2021.at["ALUNO-71", "pedra"] = "Quartzo"
df_2021.at["ALUNO-506", "pedra"] = "Quartzo"

# %%
df_2021[df_2021["pedra"].isna()]["pedra"] = "Quartzo"
df_2021["pedra_encoded"] = df_2021["pedra"].apply(
    lambda x: (
        1 if x == "Quartzo" else (2 if x == "Ágata" else (3 if x == "Ametista" else 4))
    )
)

# %%
print(df_2020["pedra_encoded"].unique())
print(df_2021["pedra_encoded"].unique())
print(df_2022["pedra_encoded"].unique())
# Out:
# [3 1 4 2]
# [3 4 1 2]
# [3 1 4 2]

# %% [markdown]
# ### Padroniza coluna 'anos_pm''
#
# Conta o número de anos que o aluno participa da Passos Mágicos
# - considera o ano de ingresso no df_2022
# - considera o anos_pm no df_2020

# %%
print(df_2020["anos_pm"].isna().sum())
print(df_2022["ano_ingresso"].isna().sum())
# Out:
# 0
# 0

# %%
anos_pm = 2022 - df_2022["ano_ingresso"]
df_2022["anos_pm"] = anos_pm

# %%
df_2022["anos_pm"].apply(lambda x: x - 1 if x > 0 else x)
# anos_pm = [x - 1 for x in df_2022['anos_pm'] if x > 0]
# anos_pm
# Out:
# nome
# ALUNO-2       0.0
# ALUNO-4       0.0
# ALUNO-5       2.0
# ALUNO-6       0.0
# ALUNO-7       0.0
#              ...
# ALUNO-1342    0.0
# ALUNO-1343    3.0
# ALUNO-1346    0.0
# ALUNO-1348    3.0
# ALUNO-1349    0.0
# Name: anos_pm, Length: 862, dtype: float64

# %%
df_2020["anos_pm"]
# Out:
# nome
# ALUNO-1       2
# ALUNO-3       2
# ALUNO-4       2
# ALUNO-5       1
# ALUNO-8       3
#              ..
# ALUNO-1341    1
# ALUNO-1343    2
# ALUNO-1344    2
# ALUNO-1347    1
# ALUNO-1348    2
# Name: anos_pm, Length: 703, dtype: object

# %%
index_anos_pm = df_2021.index.intersection(df_2020.index)

# %%
index_anos_pm
# Out:
# Index(['ALUNO-1', 'ALUNO-3', 'ALUNO-5', 'ALUNO-8', 'ALUNO-11', 'ALUNO-17',
#        'ALUNO-18', 'ALUNO-28', 'ALUNO-34', 'ALUNO-35',
#        ...
#        'ALUNO-1299', 'ALUNO-1302', 'ALUNO-1315', 'ALUNO-1319', 'ALUNO-1323',
#        'ALUNO-1324', 'ALUNO-1338', 'ALUNO-1343', 'ALUNO-1344', 'ALUNO-1348'],
#       dtype='object', name='nome', length=457)

# %%
print(df_2020["anos_pm"].isnull().sum())
print(df_2022["anos_pm"].isnull().sum())
# Out:
# 0
# 0

# %%
indexes_2020 = df_2020.index
indexes_2021 = df_2021.index
indexes_2022 = df_2022.index

# %%
indexes_2022.intersection(indexes_2021)
# Out:
# Index(['ALUNO-5', 'ALUNO-8', 'ALUNO-11', 'ALUNO-17', 'ALUNO-18', 'ALUNO-19',
#        'ALUNO-29', 'ALUNO-34', 'ALUNO-36', 'ALUNO-37',
#        ...
#        'ALUNO-1307', 'ALUNO-1319', 'ALUNO-1323', 'ALUNO-1324', 'ALUNO-1330',
#        'ALUNO-1334', 'ALUNO-1335', 'ALUNO-1338', 'ALUNO-1343', 'ALUNO-1348'],
#       dtype='object', name='nome', length=457)

# %%
indexes_2021.intersection(indexes_2020)
# Out:
# Index(['ALUNO-1', 'ALUNO-3', 'ALUNO-5', 'ALUNO-8', 'ALUNO-11', 'ALUNO-17',
#        'ALUNO-18', 'ALUNO-28', 'ALUNO-34', 'ALUNO-35',
#        ...
#        'ALUNO-1299', 'ALUNO-1302', 'ALUNO-1315', 'ALUNO-1319', 'ALUNO-1323',
#        'ALUNO-1324', 'ALUNO-1338', 'ALUNO-1343', 'ALUNO-1344', 'ALUNO-1348'],
#       dtype='object', name='nome', length=457)

# %%
alunos_pm_2020_2021 = indexes_2020.intersection(indexes_2021)

alunos_pm_2020_2021
# Out:
# Index(['ALUNO-1', 'ALUNO-3', 'ALUNO-5', 'ALUNO-8', 'ALUNO-11', 'ALUNO-17',
#        'ALUNO-18', 'ALUNO-28', 'ALUNO-34', 'ALUNO-35',
#        ...
#        'ALUNO-1299', 'ALUNO-1302', 'ALUNO-1315', 'ALUNO-1319', 'ALUNO-1323',
#        'ALUNO-1324', 'ALUNO-1338', 'ALUNO-1343', 'ALUNO-1344', 'ALUNO-1348'],
#       dtype='object', name='nome', length=457)

# %%
# há 143 nulls que preciso ainda tratar
for i in alunos_pm_2020_2021:
    df_2021.at[i, "anos_pm"] = int(df_2020.at[i, "anos_pm"]) + 1

df_2021["anos_pm"].head()
# Out:
# nome
# ALUNO-1     3.0
# ALUNO-3     3.0
# ALUNO-5     2.0
# ALUNO-8     4.0
# ALUNO-11    1.0
# Name: anos_pm, dtype: float64

# %%
df_2021["anos_pm"].isnull().sum()
# Out:
# np.int64(229)

# %%
alunos_pm_2021_2022 = indexes_2021.intersection(indexes_2022)

# %%
for i in alunos_pm_2021_2022:
    if pd.isnull(df_2021.at[i, "anos_pm"]):
        df_2021.at[i, "anos_pm"] = int(df_2022.at[i, "anos_pm"]) - 1
df_2021["anos_pm"].isnull().sum()
# Out:
# np.int64(86)

# %%
idxs = df_2021[df_2021["anos_pm"].isnull()].index

# %%
# assumir anos_pm como 0 para alunos que só aparecem em 2021
for i in idxs:
    df_2021.loc[i, "anos_pm"] = 0

df_2021["anos_pm"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Padroniza coluna 'nivel_ideal'

# %%
df_2021["nivel_ideal"].unique()
# Out:
# array(['Nível 3 (7o e 8o ano)', 'Nível 2 (5o e 6o ano)',
#        'Nível 5 (1o EM)', 'Nível 1 (4o ano)', 'Nível 4 (9o ano)',
#        'Nível 8 (Universitários)', 'Nível 6 (2o EM)',
#        'ALFA  (2o e 3o ano)', 'Nível 7 (3o EM)', 'ERRO'], dtype=object)

# %%
df_2022["nivel_ideal"].unique()
# Out:
# array(['Fase 2 (5º e 6º ano)', 'Fase 3 (7º e 8º ano)', 'Fase 6 (2º EM)',
#        'ALFA  (2º e 3º ano)', 'Fase 1 (4º ano)', 'Fase 4 (9º ano)',
#        'Fase 8 (Universitários)', 'Fase 5 (1º EM)', 'Fase 7 (3º EM)'],
#       dtype=object)

# %%
# "ALFA  (2º e 3º ano)".split("(")[0].strip()
"Fase 2 (5º e 6º ano)".split("(")[0].split(" ")[1]
# Out:
# '2'

# %%
def from_nivel_ideal_to_fase_ideal(x):
    if x != "ERRO":
        y = x.split("(")[0].strip()
        if len(y) > 0 and y != "ALFA":
            return str(y).split(" ")[1]
        elif y == "ALFA":
            return "0"
        else:
            return ""


df_2022["fase_ideal"] = df_2022["nivel_ideal"].apply(from_nivel_ideal_to_fase_ideal)
df_2021["fase_ideal"] = df_2021["nivel_ideal"].apply(from_nivel_ideal_to_fase_ideal)

print(df_2021["fase_ideal"].unique())
print(df_2022["fase_ideal"].unique())
# Out:
# ['3' '2' '5' '1' '4' '8' '6' '0' '7' None]
# ['2' '3' '6' '0' '1' '4' '8' '5' '7']

# %%
df_2022["fase_ideal"] = (
    df_2022["fase_ideal"].map(lambda x: np.nan if x == "" else x).astype(float)
)
df_2021["fase_ideal"] = (
    df_2021["fase_ideal"].map(lambda x: np.nan if x == "" else x).astype(float)
)

print(df_2021["fase_ideal"].unique())
print(df_2022["fase_ideal"].unique())
# Out:
# [ 3.  2.  5.  1.  4.  8.  6.  0.  7. nan]
# [2. 3. 6. 0. 1. 4. 8. 5. 7.]

# %% [markdown]
# ### Padroniza colunas 'rec_ava', 'rec_equipe' e 'destaque'

# %%
# destaque
print("2020: ", df_2020.columns[df_2020.columns.str.contains("destaque")].tolist())
print("2021: ", df_2021.columns[df_2021.columns.str.contains("destaque")].tolist())
print("2022: ", df_2022.columns[df_2022.columns.str.contains("destaque")].tolist())

# rec_ava
print("2020: ", df_2020.columns[df_2020.columns.str.contains("rec_ava")].tolist())
print("2021: ", df_2021.columns[df_2021.columns.str.contains("rec_ava")].tolist())
print("2022: ", df_2022.columns[df_2022.columns.str.contains("rec_ava")].tolist())

# rec_equipe
print("2020: ", df_2020.columns[df_2020.columns.str.contains("rec_equipe")].tolist())
print("2021: ", df_2021.columns[df_2021.columns.str.contains("rec_equipe")].tolist())
print("2022: ", df_2022.columns[df_2022.columns.str.contains("rec_equipe")].tolist())
# Out:
# 2020:  ['destaque_ieg', 'destaque_ida', 'destaque_ipv']
# 2021:  []
# 2022:  ['destaque_ieg', 'destaque_ida', 'destaque_ipv']
# 2020:  []
# 2021:  []
# 2022:  ['rec_ava_1', 'rec_ava_2', 'rec_ava_3', 'rec_ava_4']
# 2020:  []
# 2021:  ['rec_equipe_1', 'rec_equipe_2', 'rec_equipe_3', 'rec_equipe_4']
# 2022:  []

# %% [markdown]
# #### Ordinal encoding para as colunas 'rec_ava', 'rec_equipe' e 'destaque'

# %%
cols_destaque_2020 = df_2020.columns[df_2020.columns.str.contains("destaque")].tolist()
for col in cols_destaque_2020:
    print("2020: ", col, ":", df_2020[col].unique())
    print("2022: ", col, ":", df_2022[col].unique())
# Out:
# 2020:  destaque_ieg : ['Seu destaque em 2020: A sua boa entrega das lições de casa.'
#  'Ponto a melhorar em 2021: Melhorar a sua entrega de lições de casa.']
# 2022:  destaque_ieg : ['Destaque: A sua boa entrega das lições de casa.'
#  'Melhorar: Melhorar a sua entrega de lições de casa.']
# 2020:  destaque_ida : ['Ponto a melhorar em 2021: Empenhar-se mais nas aulas e avaliações.'
#  'Seu destaque em 2020: As suas boas notas na Passos Mágicos.']
# 2022:  destaque_ida : ['Destaque: As suas boas notas na Passos Mágicos.'
#  'Melhorar: Empenhar-se mais nas aulas e avaliações.']
# 2020:  destaque_ipv : ['Seu destaque em 2020: A sua boa integração aos Princípios Passos Mágicos.'
#  'Ponto a melhorar em 2021: Integrar-se mais aos Princípios Passos Mágicos.']
# 2022:  destaque_ipv : ['Destaque: A sua boa integração aos Princípios Passos Mágicos.'
#  'Melhorar: Integrar-se mais aos Princípios Passos Mágicos.']

# %%
cols_rec_ava_2022 = df_2022.columns[df_2022.columns.str.contains("rec_ava")].tolist()
for col in cols_rec_ava_2022:
    print("2022: ", col, ":", df_2022[col].unique())
# Out:
# 2022:  rec_ava_1 : ['Mantido na Fase + Bolsa' 'Promovido de Fase' 'Mantido na Fase atual'
#  'Promovido de Fase + Bolsa' 'Não avaliado' 'Alocado em Fase anterior']
# 2022:  rec_ava_2 : ['Mantido na Fase atual' 'Promovido de Fase' 'Não avaliado'
#  'Promovido de Fase + Bolsa' 'Mantido na Fase + Bolsa']
# 2022:  rec_ava_3 : [nan 'Promovido de Fase' 'Mantido na Fase atual'
#  'Promovido de Fase + Bolsa' 'Mantido na Fase + Bolsa'
#  'Alocado em Fase anterior']
# 2022:  rec_ava_4 : [nan 'Promovido de Fase' 'Promovido de Fase + Bolsa'
#  'Mantido na Fase atual' 'Mantido na Fase + Bolsa'
#  'Alocado em Fase anterior']

# %%
cols_rec_equipe_2021 = df_2021.columns[
    df_2021.columns.str.contains("rec_equipe")
].tolist()
for col in cols_rec_equipe_2021:
    print("2021: ", col, ":", df_2021[col].unique())
# Out:
# 2021:  rec_equipe_1 : ['Promovido de Fase' 'Promovido de Fase + Bolsa' 'Não avaliado'
#  'Mantido na Fase atual' 'Mantido na Fase + Bolsa'
#  'Alocado em Fase anterior']
# 2021:  rec_equipe_2 : ['Promovido de Fase' 'Mantido na Fase atual' 'Não avaliado'
#  'Promovido de Fase + Bolsa' 'Mantido na Fase + Bolsa'
#  'Alocado em Fase anterior']
# 2021:  rec_equipe_3 : ['Mantido na Fase atual' 'Promovido de Fase' 'Não avaliado'
#  'Mantido na Fase + Bolsa' 'Promovido de Fase + Bolsa'
#  'Alocado em Fase anterior']
# 2021:  rec_equipe_4 : ['Não avaliado' 'Mantido na Fase atual' 'Promovido de Fase'
#  'Promovido de Fase + Bolsa' 'Mantido na Fase + Bolsa'
#  'Alocado em Fase anterior']

# %% [markdown]
# ##### NLP para análise de sentimento das colunas 'rec_ava', 'rec_equipe' e 'destaque'

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import RSLPStemmer
import pandas as pd
import unidecode

# Download necessary NLTK data
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("rslp")


def preprocess_text(text):
    if pd.isna(text):
        return ""

    # Convert to lowercase
    text = text.lower()

    # Remove accents
    text = unidecode.unidecode(text)

    # Remove special characters and digits
    text = re.sub(r"[^a-z\s]", "", text)

    # Tokenize
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words("portuguese"))
    tokens = [token for token in tokens if token not in stop_words]

    # Stemming
    stemmer = RSLPStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    return " ".join(tokens)


def analyze_sentiment(text, positive_words, negative_words, neutral_words=[]):
    if any(word in text for word in positive_words):
        return "Positivo"
    elif any(word in text for word in negative_words):
        return "Negativo"
    elif any(word in text for word in neutral_words):
        return "Neutro"
    else:
        return np.nan
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\carlo.000\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\carlo.000\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\carlo.000\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package rslp to
# [nltk_data]     C:\Users\carlo.000\AppData\Roaming\nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %%
destaque_2020 = df_2020[
    df_2020.columns[df_2020.columns.str.contains("destaque")]
].copy()
destaque_2022 = df_2022[
    df_2022.columns[df_2022.columns.str.contains("destaque")]
].copy()
rec_ava_2022 = df_2022[df_2022.columns[df_2022.columns.str.contains("rec_ava")]].copy()
rec_equipe_2021 = df_2021[
    df_2021.columns[df_2021.columns.str.contains("rec_equipe")]
].copy()

# %%
for col in destaque_2020.columns:
    destaque_2020[col] = destaque_2020[col].apply(preprocess_text)

for col in destaque_2022.columns:
    destaque_2022[col] = destaque_2022[col].apply(preprocess_text)

for col in rec_ava_2022.columns:
    rec_ava_2022[col] = rec_ava_2022[col].apply(preprocess_text)

for col in rec_equipe_2021.columns:
    rec_equipe_2021[col] = rec_equipe_2021[col].apply(preprocess_text)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


def generate_wordcloud(text, title):
    wordcloud = WordCloud(width=800, height=400, background_color="white").generate(
        text
    )

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.title(title)
    plt.show()

# %%
def generate_word_stats(text):
    # Print some statistics
    words = word_tokenize(text)
    word_freq = nltk.FreqDist(words)
    print(f"Total words: {len(words)}")
    print(f"Unique words: {len(set(words))}")
    print(f"Most common words: {word_freq.most_common(10)}")

# %% [markdown]
# ##### palavras mais comuns em destaque_2020

# %%
for col in destaque_2020.columns:
    text = " ".join(destaque_2022[col].dropna())
    generate_wordcloud(text, col)
    generate_word_stats(text)
# Out:
# Total words: 4310
# Unique words: 6
# Most common words: [('entreg', 862), ('lico', 862), ('cas', 862), ('destaqu', 577), ('boa', 577), ('melhor', 570)]
# Total words: 3687
# Unique words: 9
# Most common words: [('melhor', 623), ('empenhars', 623), ('aul', 623), ('avaliaco', 623), ('destaqu', 239), ('boa', 239), ('not', 239), ('pass', 239), ('magic', 239)]
# Total words: 4687
# Unique words: 8
# Most common words: [('principi', 862), ('pass', 862), ('magic', 862), ('melhor', 485), ('integrars', 485), ('destaqu', 377), ('boa', 377), ('integraca', 377)]

# %% [markdown]
# ##### palavras mais comuns em destaque_2022

# %%
for col in destaque_2022.columns:
    text = " ".join(destaque_2022[col].dropna())
    generate_wordcloud(text, col)
    generate_word_stats(text)
# Out:
# Total words: 4310
# Unique words: 6
# Most common words: [('entreg', 862), ('lico', 862), ('cas', 862), ('destaqu', 577), ('boa', 577), ('melhor', 570)]
# Total words: 3687
# Unique words: 9
# Most common words: [('melhor', 623), ('empenhars', 623), ('aul', 623), ('avaliaco', 623), ('destaqu', 239), ('boa', 239), ('not', 239), ('pass', 239), ('magic', 239)]
# Total words: 4687
# Unique words: 8
# Most common words: [('principi', 862), ('pass', 862), ('magic', 862), ('melhor', 485), ('integrars', 485), ('destaqu', 377), ('boa', 377), ('integraca', 377)]

# %% [markdown]
# ##### palavras mais comuns em rec_ava_2022

# %%
for col in rec_ava_2022.columns:
    text = " ".join(rec_ava_2022[col].dropna())
    generate_wordcloud(text, col)
    generate_word_stats(text)
# Out:
# Total words: 2294
# Unique words: 9
# Most common words: [('fas', 860), ('promov', 430), ('mant', 429), ('atual', 422), ('bols', 147), ('nao', 2), ('avali', 2), ('aloc', 1), ('anteri', 1)]
# Total words: 2324
# Unique words: 7
# Most common words: [('fas', 860), ('mant', 574), ('atual', 571), ('promov', 286), ('bols', 29), ('nao', 2), ('avali', 2)]
# Total words: 1631
# Unique words: 7
# Most common words: [('fas', 626), ('mant', 322), ('atual', 304), ('promov', 298), ('bols', 69), ('aloc', 6), ('anteri', 6)]
# Total words: 777
# Unique words: 7
# Most common words: [('fas', 285), ('promov', 169), ('bols', 104), ('mant', 78), ('atual', 65), ('aloc', 38), ('anteri', 38)]

# %% [markdown]
# #### palavras mais comuns em rec_equipe_2021

# %%
for col in rec_equipe_2021.columns:
    text = " ".join(rec_equipe_2021[col].dropna())
    generate_wordcloud(text, col)
    generate_word_stats(text)
# Out:
# Total words: 1794
# Unique words: 9
# Most common words: [('fas', 673), ('promov', 351), ('mant', 314), ('atual', 309), ('bols', 105), ('nao', 13), ('avali', 13), ('aloc', 8), ('anteri', 8)]
# Total words: 1847
# Unique words: 9
# Most common words: [('fas', 668), ('mant', 364), ('atual', 348), ('promov', 295), ('bols', 118), ('nao', 18), ('avali', 18), ('aloc', 9), ('anteri', 9)]
# Total words: 1740
# Unique words: 9
# Most common words: [('fas', 543), ('mant', 279), ('atual', 275), ('promov', 263), ('nao', 143), ('avali', 143), ('bols', 92), ('aloc', 1), ('anteri', 1)]
# Total words: 1441
# Unique words: 9
# Most common words: [('nao', 542), ('avali', 542), ('fas', 144), ('promov', 91), ('mant', 52), ('atual', 51), ('bols', 17), ('aloc', 1), ('anteri', 1)]

# %% [markdown]
# #### rec_ava_2022 e rec_equipe_2021
#
# São colunas que possuem praticamente o mesmo conteúdo, então serão uniformizadas.

# %%
for col in rec_ava_2022.columns:
    print(col, ":", rec_ava_2022[col].value_counts())
# Out:
# rec_ava_1 : rec_ava_1
# mant fas atual     422
# promov fas         290
# promov fas bols    140
# mant fas bols        7
# nao avali            2
# aloc fas anteri      1
# Name: count, dtype: int64
# rec_ava_2 : rec_ava_2
# mant fas atual     571
# promov fas         260
# promov fas bols     26
# mant fas bols        3
# nao avali            2
# Name: count, dtype: int64
# rec_ava_3 : rec_ava_3
# mant fas atual     304
# promov fas         247
#                    236
# promov fas bols     51
# mant fas bols       18
# aloc fas anteri      6
# Name: count, dtype: int64
# rec_ava_4 : rec_ava_4
#                    577
# promov fas bols     91
# promov fas          78
# mant fas atual      65
# aloc fas anteri     38
# mant fas bols       13
# Name: count, dtype: int64

# %%
positive_words = ["promov", "bol"]
negative_words = ["aloc", "anter"]
neutral_words = ["mant", "atual"]

for col in rec_ava_2022.columns:
    rec_ava_2022[f"{col}_resultado"] = rec_ava_2022[col].apply(
        analyze_sentiment,
        positive_words=positive_words,
        negative_words=negative_words,
        neutral_words=neutral_words,
    )

rec_ava_2022
# Out:
#                  rec_ava_1       rec_ava_2       rec_ava_3      rec_ava_4  \
# nome
# ALUNO-2      mant fas bols  mant fas atual
# ALUNO-4         promov fas  mant fas atual      promov fas
# ALUNO-5     mant fas atual      promov fas  mant fas atual
# ALUNO-6     mant fas atual      promov fas  mant fas atual
# ALUNO-7         promov fas      promov fas
# ...                    ...             ...             ...            ...
# ALUNO-1342  mant fas atual      promov fas  mant fas atual
# ALUNO-1343  mant fas atual      promov fas  mant fas atual
# ALUNO-1346      promov fas      promov fas
# ALUNO-1348  mant fas atual  mant fas atual      promov fas     promov fas
# ALUNO-1349      promov fas  mant fas atual      promov fas  mant fas bols
#
#            rec_ava_1_resultado rec_ava_2_resultado rec_ava_3_resultado  \
# nome
# ALUNO-2               Positivo              Neutro                 NaN
# ALUNO-4               Positivo              Neutro            Positivo
# ALUNO-5                 Neutro            Positivo              Neutro
# ALUNO-6                 Neutro            Positivo              Neutro
# ALUNO-7               Positivo            Positivo                 NaN
# ...                        ...                 ...                 ...
# ALUNO-1342              Neutro            Positivo              Neutro
# ALUNO-1343              Neutro            Positivo              Neutro
# ALUNO-1346            Positivo            Positivo                 NaN
# ALUNO-1348              Neutro              Neutro            Positivo
# ALUNO-1349            Positivo              Neutro            Positivo
#
#            rec_ava_4_resultado
# nome
# ALUNO-2                    NaN
# ALUNO-4                    NaN
# ALUNO-5                    NaN
# ALUNO-6                    NaN
# ALUNO-7                    NaN
# ...                        ...
# ALUNO-1342                 NaN
# ALUNO-1343                 NaN
# ALUNO-1346                 NaN
# ALUNO-1348            Positivo
# ALUNO-1349            Positivo
#
# [862 rows x 8 columns]

# %%
for col in rec_equipe_2021.columns:
    print(col, ":", rec_equipe_2021[col].value_counts())
# Out:
# rec_equipe_1 : rec_equipe_1
# mant fas atual     309
# promov fas         251
# promov fas bols    100
# nao avali           13
# aloc fas anteri      8
# mant fas bols        5
# Name: count, dtype: int64
# rec_equipe_2 : rec_equipe_2
# mant fas atual     348
# promov fas         193
# promov fas bols    102
# nao avali           18
# mant fas bols       16
# aloc fas anteri      9
# Name: count, dtype: int64
# rec_equipe_3 : rec_equipe_3
# mant fas atual     275
# promov fas         175
# nao avali          143
# promov fas bols     88
# mant fas bols        4
# aloc fas anteri      1
# Name: count, dtype: int64
# rec_equipe_4 : rec_equipe_4
# nao avali          542
# promov fas          75
# mant fas atual      51
# promov fas bols     16
# mant fas bols        1
# aloc fas anteri      1
# Name: count, dtype: int64

# %%
for col in rec_equipe_2021.columns:
    rec_equipe_2021[f"{col}_resultado"] = rec_equipe_2021[col].apply(
        analyze_sentiment,
        positive_words=positive_words,
        negative_words=negative_words,
        neutral_words=neutral_words,
    )

rec_equipe_2021
# Out:
#                rec_equipe_1     rec_equipe_2    rec_equipe_3    rec_equipe_4  \
# nome
# ALUNO-1          promov fas       promov fas  mant fas atual       nao avali
# ALUNO-3          promov fas       promov fas  mant fas atual       nao avali
# ALUNO-5          promov fas   mant fas atual  mant fas atual       nao avali
# ALUNO-8     promov fas bols       promov fas      promov fas  mant fas atual
# ALUNO-11         promov fas   mant fas atual  mant fas atual       nao avali
# ...                     ...              ...             ...             ...
# ALUNO-1338       promov fas       promov fas  mant fas atual       nao avali
# ALUNO-1343   mant fas atual        nao avali  mant fas atual       nao avali
# ALUNO-1344   mant fas atual       promov fas  mant fas atual       nao avali
# ALUNO-1345   mant fas atual   mant fas atual       nao avali       nao avali
# ALUNO-1348       promov fas  promov fas bols      promov fas       nao avali
#
#            rec_equipe_1_resultado rec_equipe_2_resultado  \
# nome
# ALUNO-1                  Positivo               Positivo
# ALUNO-3                  Positivo               Positivo
# ALUNO-5                  Positivo                 Neutro
# ALUNO-8                  Positivo               Positivo
# ALUNO-11                 Positivo                 Neutro
# ...                           ...                    ...
# ALUNO-1338               Positivo               Positivo
# ALUNO-1343                 Neutro                    NaN
# ALUNO-1344                 Neutro               Positivo
# ALUNO-1345                 Neutro                 Neutro
# ALUNO-1348               Positivo               Positivo
#
#            rec_equipe_3_resultado rec_equipe_4_resultado
# nome
# ALUNO-1                    Neutro                    NaN
# ALUNO-3                    Neutro                    NaN
# ALUNO-5                    Neutro                    NaN
# ALUNO-8                  Positivo                 Neutro
# ALUNO-11                   Neutro                    NaN
# ...                           ...                    ...
# ALUNO-1338                 Neutro                    NaN
# ALUNO-1343                 Neutro                    NaN
# ALUNO-1344                 Neutro                    NaN
# ALUNO-1345                    NaN                    NaN
# ALUNO-1348               Positivo                    NaN
#
# [686 rows x 8 columns]

# %% [markdown]
# #### colunas de destaque

# %%
for col in destaque_2020.columns:
    print(col, ":", destaque_2020[col].value_counts())
# Out:
# destaque_ieg : destaque_ieg
# destaqu boa entreg lico cas           476
# pont melhor melhor entreg lico cas    227
# Name: count, dtype: int64
# destaque_ida : destaque_ida
# pont melhor empenhars aul avaliaco    404
# destaqu boa not pass magic            299
# Name: count, dtype: int64
# destaque_ipv : destaque_ipv
# pont melhor integrars principi pass magic    368
# destaqu boa integraca principi pass magic    335
# Name: count, dtype: int64

# %%
for col in destaque_2022.columns:
    print(col, ":", destaque_2022[col].value_counts())
# Out:
# destaque_ieg : destaque_ieg
# destaqu boa entreg lico cas      577
# melhor melhor entreg lico cas    285
# Name: count, dtype: int64
# destaque_ida : destaque_ida
# melhor empenhars aul avaliaco    623
# destaqu boa not pass magic       239
# Name: count, dtype: int64
# destaque_ipv : destaque_ipv
# melhor integrars principi pass magic         485
# destaqu boa integraca principi pass magic    377
# Name: count, dtype: int64

# %%
positive_words = ["destaqu", "boa"]
negative_words = ["melhor", "empenh"]

for col in destaque_2020.columns:
    destaque_2020[f"{col}_resultado"] = destaque_2020[col].apply(
        analyze_sentiment, positive_words=positive_words, negative_words=negative_words
    )
destaque_2020.head()
# Out:
#                                destaque_ieg  \
# nome
# ALUNO-1         destaqu boa entreg lico cas
# ALUNO-3         destaqu boa entreg lico cas
# ALUNO-4  pont melhor melhor entreg lico cas
# ALUNO-5         destaqu boa entreg lico cas
# ALUNO-8         destaqu boa entreg lico cas
#
#                                destaque_ida  \
# nome
# ALUNO-1  pont melhor empenhars aul avaliaco
# ALUNO-3  pont melhor empenhars aul avaliaco
# ALUNO-4  pont melhor empenhars aul avaliaco
# ALUNO-5          destaqu boa not pass magic
# ALUNO-8  pont melhor empenhars aul avaliaco
#
#                                       destaque_ipv destaque_ieg_resultado  \
# nome
# ALUNO-1  destaqu boa integraca principi pass magic               Positivo
# ALUNO-3  destaqu boa integraca principi pass magic               Positivo
# ALUNO-4  pont melhor integrars principi pass magic               Negativo
# ALUNO-5  destaqu boa integraca principi pass magic               Positivo
# ALUNO-8  destaqu boa integraca principi pass magic               Positivo
#
#         destaque_ida_resultado destaque_ipv_resultado
# nome
# ALUNO-1               Negativo               Positivo
# ALUNO-3               Negativo               Positivo
# ALUNO-4               Negativo               Negativo
# ALUNO-5               Positivo               Positivo
# ALUNO-8               Negativo               Positivo

# %%
for col in destaque_2022.columns:
    destaque_2022[f"{col}_resultado"] = destaque_2022[col].apply(
        analyze_sentiment, positive_words=positive_words, negative_words=negative_words
    )
destaque_2022.head()
# Out:
#                         destaque_ieg                   destaque_ida  \
# nome
# ALUNO-2  destaqu boa entreg lico cas     destaqu boa not pass magic
# ALUNO-4  destaqu boa entreg lico cas  melhor empenhars aul avaliaco
# ALUNO-5  destaqu boa entreg lico cas  melhor empenhars aul avaliaco
# ALUNO-6  destaqu boa entreg lico cas  melhor empenhars aul avaliaco
# ALUNO-7  destaqu boa entreg lico cas  melhor empenhars aul avaliaco
#
#                                       destaque_ipv destaque_ieg_resultado  \
# nome
# ALUNO-2  destaqu boa integraca principi pass magic               Positivo
# ALUNO-4  destaqu boa integraca principi pass magic               Positivo
# ALUNO-5  destaqu boa integraca principi pass magic               Positivo
# ALUNO-6  destaqu boa integraca principi pass magic               Positivo
# ALUNO-7  destaqu boa integraca principi pass magic               Positivo
#
#         destaque_ida_resultado destaque_ipv_resultado
# nome
# ALUNO-2               Positivo               Positivo
# ALUNO-4               Negativo               Positivo
# ALUNO-5               Negativo               Positivo
# ALUNO-6               Negativo               Positivo
# ALUNO-7               Negativo               Positivo

# %% [markdown]
# ### Encoding das colunas com avaliação de sentimento

# %%
# ordinal encoding das colunas com avaliação de sentimento destaque, rec_ava e rec_equipe
# - Negativo = -1
# - Neutro = 0
# - Positivo = 1
cols_destaque_resultado = destaque_2020.columns[
    destaque_2020.columns.str.contains("resultado")
].tolist()
cols_destaque_resultado = destaque_2022.columns[
    destaque_2022.columns.str.contains("resultado")
].tolist()
cols_rec_ava_resultado = rec_ava_2022.columns[
    rec_ava_2022.columns.str.contains("resultado")
].tolist()
cols_rec_equipe_resultado = rec_equipe_2021.columns[
    rec_equipe_2021.columns.str.contains("resultado")
].tolist()


def encode_sentiment(text):
    if text == "Negativo":
        return -1
    elif text == "Neutro":
        return 0
    elif text == "Positivo":
        return 1
    else:
        return np.nan


for col in cols_destaque_resultado:
    destaque_2020[f"{col}_encoded"] = destaque_2020[col].apply(encode_sentiment)

for col in cols_destaque_resultado:
    destaque_2022[f"{col}_encoded"] = destaque_2022[col].apply(encode_sentiment)

for col in cols_rec_ava_resultado:
    rec_ava_2022[f"{col}_encoded"] = rec_ava_2022[col].apply(encode_sentiment)

for col in cols_rec_equipe_resultado:
    rec_equipe_2021[f"{col}_encoded"] = rec_equipe_2021[col].apply(encode_sentiment)

# %%
destaque_2020.head()
# Out:
#                                destaque_ieg  \
# nome
# ALUNO-1         destaqu boa entreg lico cas
# ALUNO-3         destaqu boa entreg lico cas
# ALUNO-4  pont melhor melhor entreg lico cas
# ALUNO-5         destaqu boa entreg lico cas
# ALUNO-8         destaqu boa entreg lico cas
#
#                                destaque_ida  \
# nome
# ALUNO-1  pont melhor empenhars aul avaliaco
# ALUNO-3  pont melhor empenhars aul avaliaco
# ALUNO-4  pont melhor empenhars aul avaliaco
# ALUNO-5          destaqu boa not pass magic
# ALUNO-8  pont melhor empenhars aul avaliaco
#
#                                       destaque_ipv destaque_ieg_resultado  \
# nome
# ALUNO-1  destaqu boa integraca principi pass magic               Positivo
# ALUNO-3  destaqu boa integraca principi pass magic               Positivo
# ALUNO-4  pont melhor integrars principi pass magic               Negativo
# ALUNO-5  destaqu boa integraca principi pass magic               Positivo
# ALUNO-8  destaqu boa integraca principi pass magic               Positivo
#
#         destaque_ida_resultado destaque_ipv_resultado  \
# nome
# ALUNO-1               Negativo               Positivo
# ALUNO-3               Negativo               Positivo
# ALUNO-4               Negativo               Negativo
# ALUNO-5               Positivo               Positivo
# ALUNO-8               Negativo               Positivo
#
#          destaque_ieg_resultado_encoded  destaque_ida_resultado_encoded  \
# nome
# ALUNO-1                               1                              -1
# ALUNO-3                               1                              -1
# ALUNO-4                              -1                              -1
# ALUNO-5                               1                               1
# ALUNO-8                               1                              -1
#
#          destaque_ipv_resultado_encoded
# nome
# ALUNO-1                               1
# ALUNO-3                               1
# ALUNO-4                              -1
# ALUNO-5                               1
# ALUNO-8                               1

# %%
destaque_2022.head()
# Out:
#                         destaque_ieg                   destaque_ida  \
# nome
# ALUNO-2  destaqu boa entreg lico cas     destaqu boa not pass magic
# ALUNO-4  destaqu boa entreg lico cas  melhor empenhars aul avaliaco
# ALUNO-5  destaqu boa entreg lico cas  melhor empenhars aul avaliaco
# ALUNO-6  destaqu boa entreg lico cas  melhor empenhars aul avaliaco
# ALUNO-7  destaqu boa entreg lico cas  melhor empenhars aul avaliaco
#
#                                       destaque_ipv destaque_ieg_resultado  \
# nome
# ALUNO-2  destaqu boa integraca principi pass magic               Positivo
# ALUNO-4  destaqu boa integraca principi pass magic               Positivo
# ALUNO-5  destaqu boa integraca principi pass magic               Positivo
# ALUNO-6  destaqu boa integraca principi pass magic               Positivo
# ALUNO-7  destaqu boa integraca principi pass magic               Positivo
#
#         destaque_ida_resultado destaque_ipv_resultado  \
# nome
# ALUNO-2               Positivo               Positivo
# ALUNO-4               Negativo               Positivo
# ALUNO-5               Negativo               Positivo
# ALUNO-6               Negativo               Positivo
# ALUNO-7               Negativo               Positivo
#
#          destaque_ieg_resultado_encoded  destaque_ida_resultado_encoded  \
# nome
# ALUNO-2                               1                               1
# ALUNO-4                               1                              -1
# ALUNO-5                               1                              -1
# ALUNO-6                               1                              -1
# ALUNO-7                               1                              -1
#
#          destaque_ipv_resultado_encoded
# nome
# ALUNO-2                               1
# ALUNO-4                               1
# ALUNO-5                               1
# ALUNO-6                               1
# ALUNO-7                               1

# %%
rec_ava_2022.head()
# Out:
#               rec_ava_1       rec_ava_2       rec_ava_3 rec_ava_4  \
# nome
# ALUNO-2   mant fas bols  mant fas atual
# ALUNO-4      promov fas  mant fas atual      promov fas
# ALUNO-5  mant fas atual      promov fas  mant fas atual
# ALUNO-6  mant fas atual      promov fas  mant fas atual
# ALUNO-7      promov fas      promov fas
#
#         rec_ava_1_resultado rec_ava_2_resultado rec_ava_3_resultado  \
# nome
# ALUNO-2            Positivo              Neutro                 NaN
# ALUNO-4            Positivo              Neutro            Positivo
# ALUNO-5              Neutro            Positivo              Neutro
# ALUNO-6              Neutro            Positivo              Neutro
# ALUNO-7            Positivo            Positivo                 NaN
#
#         rec_ava_4_resultado  rec_ava_1_resultado_encoded  \
# nome
# ALUNO-2                 NaN                          1.0
# ALUNO-4                 NaN                          1.0
# ALUNO-5                 NaN                          0.0
# ALUNO-6                 NaN                          0.0
# ALUNO-7                 NaN                          1.0
#
#          rec_ava_2_resultado_encoded  rec_ava_3_resultado_encoded  \
# nome
# ALUNO-2                          0.0                          NaN
# ALUNO-4                          0.0                          1.0
# ALUNO-5                          1.0                          0.0
# ALUNO-6                          1.0                          0.0
# ALUNO-7                          1.0                          NaN
#
#          rec_ava_4_resultado_encoded
# nome
# ALUNO-2                          NaN
# ALUNO-4                          NaN
# ALUNO-5                          NaN
# ALUNO-6                          NaN
# ALUNO-7                          NaN

# %%
rec_equipe_2021.head()
# Out:
#              rec_equipe_1    rec_equipe_2    rec_equipe_3    rec_equipe_4  \
# nome
# ALUNO-1        promov fas      promov fas  mant fas atual       nao avali
# ALUNO-3        promov fas      promov fas  mant fas atual       nao avali
# ALUNO-5        promov fas  mant fas atual  mant fas atual       nao avali
# ALUNO-8   promov fas bols      promov fas      promov fas  mant fas atual
# ALUNO-11       promov fas  mant fas atual  mant fas atual       nao avali
#
#          rec_equipe_1_resultado rec_equipe_2_resultado rec_equipe_3_resultado  \
# nome
# ALUNO-1                Positivo               Positivo                 Neutro
# ALUNO-3                Positivo               Positivo                 Neutro
# ALUNO-5                Positivo                 Neutro                 Neutro
# ALUNO-8                Positivo               Positivo               Positivo
# ALUNO-11               Positivo                 Neutro                 Neutro
#
#          rec_equipe_4_resultado  rec_equipe_1_resultado_encoded  \
# nome
# ALUNO-1                     NaN                             1.0
# ALUNO-3                     NaN                             1.0
# ALUNO-5                     NaN                             1.0
# ALUNO-8                  Neutro                             1.0
# ALUNO-11                    NaN                             1.0
#
#           rec_equipe_2_resultado_encoded  rec_equipe_3_resultado_encoded  \
# nome
# ALUNO-1                              1.0                             0.0
# ALUNO-3                              1.0                             0.0
# ALUNO-5                              0.0                             0.0
# ALUNO-8                              1.0                             1.0
# ALUNO-11                             0.0                             0.0
#
#           rec_equipe_4_resultado_encoded
# nome
# ALUNO-1                              NaN
# ALUNO-3                              NaN
# ALUNO-5                              NaN
# ALUNO-8                              0.0
# ALUNO-11                             NaN

# %% [markdown]
# ### Definição da coluna `in_fase` para sinalizar se o aluno está ou não de acordo com a sua fase (df_2021, e df_2022):
#   - fase - fase_ideal: se 0, está na fase; se < 0, abaixo da fase; se > 0, acima da fase

# %%
defasagem = df_2022["fase"] - df_2022["fase_ideal"]
defasagem.value_counts()
# Out:
# -1.0    412
#  0.0    247
# -2.0    163
# -3.0     23
#  1.0      9
# -4.0      4
#  2.0      3
# -5.0      1
# Name: count, dtype: int64

# %%
defasagem.isnull().sum()
# Out:
# np.int64(0)

# %%
df_2022[df_2022["fase_ideal"].isna()]["ano_ingresso"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_2021["defasagem"].value_counts()
# Out:
# defasagem
# -1.0    317
#  0.0    249
# -2.0     93
#  1.0     16
# -3.0      8
# -4.0      2
#  3.0      1
# Name: count, dtype: int64

# %%
df_2021["defasagem"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### síntese dos indicadores de rec_ava e rec_equipe

# %%
import math

# %%
rec_ava_2022.head()
# Out:
#               rec_ava_1       rec_ava_2       rec_ava_3 rec_ava_4  \
# nome
# ALUNO-2   mant fas bols  mant fas atual
# ALUNO-4      promov fas  mant fas atual      promov fas
# ALUNO-5  mant fas atual      promov fas  mant fas atual
# ALUNO-6  mant fas atual      promov fas  mant fas atual
# ALUNO-7      promov fas      promov fas
#
#         rec_ava_1_resultado rec_ava_2_resultado rec_ava_3_resultado  \
# nome
# ALUNO-2            Positivo              Neutro                 NaN
# ALUNO-4            Positivo              Neutro            Positivo
# ALUNO-5              Neutro            Positivo              Neutro
# ALUNO-6              Neutro            Positivo              Neutro
# ALUNO-7            Positivo            Positivo                 NaN
#
#         rec_ava_4_resultado  rec_ava_1_resultado_encoded  \
# nome
# ALUNO-2                 NaN                          1.0
# ALUNO-4                 NaN                          1.0
# ALUNO-5                 NaN                          0.0
# ALUNO-6                 NaN                          0.0
# ALUNO-7                 NaN                          1.0
#
#          rec_ava_2_resultado_encoded  rec_ava_3_resultado_encoded  \
# nome
# ALUNO-2                          0.0                          NaN
# ALUNO-4                          0.0                          1.0
# ALUNO-5                          1.0                          0.0
# ALUNO-6                          1.0                          0.0
# ALUNO-7                          1.0                          NaN
#
#          rec_ava_4_resultado_encoded
# nome
# ALUNO-2                          NaN
# ALUNO-4                          NaN
# ALUNO-5                          NaN
# ALUNO-6                          NaN
# ALUNO-7                          NaN

# %%
cols_res_enc = rec_ava_2022.columns[
    rec_ava_2022.columns.str.contains("resultado_encoded")
]
value_counts_dict = rec_ava_2022[cols_res_enc].iloc[3].value_counts().to_dict()
# Filter out NaN or null-like values
filtered_dict = {k: v for k, v in value_counts_dict.items() if pd.notnull(k)}

# Find the key with the maximum frequency
most_frequent_value = max(filtered_dict, key=filtered_dict.get)

print(most_frequent_value)
# Out:
# 0.0

# %%
def get_most_frequent_value(df):
    value_counts_dict = df.value_counts().to_dict()
    # Filter out NaN or null-like values
    filtered_dict = {k: v for k, v in value_counts_dict.items() if pd.notnull(k)}

    # Find the key with the maximum frequency
    try:
        most_frequent_value = max(filtered_dict, key=filtered_dict.get)
    except:
        most_frequent_value = np.nan

    return most_frequent_value


rec_ava_sintese = []
for i in range(rec_ava_2022.shape[0]):
    rec_ava_sintese.append(get_most_frequent_value(rec_ava_2022[cols_res_enc].iloc[i]))

# %%
rec_ava_2022["rec_sintese"] = rec_ava_sintese
rec_ava_2022.head()
# Out:
#               rec_ava_1       rec_ava_2       rec_ava_3 rec_ava_4  \
# nome
# ALUNO-2   mant fas bols  mant fas atual
# ALUNO-4      promov fas  mant fas atual      promov fas
# ALUNO-5  mant fas atual      promov fas  mant fas atual
# ALUNO-6  mant fas atual      promov fas  mant fas atual
# ALUNO-7      promov fas      promov fas
#
#         rec_ava_1_resultado rec_ava_2_resultado rec_ava_3_resultado  \
# nome
# ALUNO-2            Positivo              Neutro                 NaN
# ALUNO-4            Positivo              Neutro            Positivo
# ALUNO-5              Neutro            Positivo              Neutro
# ALUNO-6              Neutro            Positivo              Neutro
# ALUNO-7            Positivo            Positivo                 NaN
#
#         rec_ava_4_resultado  rec_ava_1_resultado_encoded  \
# nome
# ALUNO-2                 NaN                          1.0
# ALUNO-4                 NaN                          1.0
# ALUNO-5                 NaN                          0.0
# ALUNO-6                 NaN                          0.0
# ALUNO-7                 NaN                          1.0
#
#          rec_ava_2_resultado_encoded  rec_ava_3_resultado_encoded  \
# nome
# ALUNO-2                          0.0                          NaN
# ALUNO-4                          0.0                          1.0
# ALUNO-5                          1.0                          0.0
# ALUNO-6                          1.0                          0.0
# ALUNO-7                          1.0                          NaN
#
#          rec_ava_4_resultado_encoded  rec_sintese
# nome
# ALUNO-2                          NaN          1.0
# ALUNO-4                          NaN          1.0
# ALUNO-5                          NaN          0.0
# ALUNO-6                          NaN          0.0
# ALUNO-7                          NaN          1.0

# %%
cols_res_enc = rec_equipe_2021.columns[
    rec_equipe_2021.columns.str.contains("resultado_encoded")
]
rec_equipe_sintese = []
for i in range(rec_equipe_2021.shape[0]):
    rec_equipe_sintese.append(
        get_most_frequent_value(rec_equipe_2021[cols_res_enc].iloc[i])
    )

rec_equipe_2021["rec_sintese"] = rec_equipe_sintese
rec_equipe_2021.head()
# Out:
#              rec_equipe_1    rec_equipe_2    rec_equipe_3    rec_equipe_4  \
# nome
# ALUNO-1        promov fas      promov fas  mant fas atual       nao avali
# ALUNO-3        promov fas      promov fas  mant fas atual       nao avali
# ALUNO-5        promov fas  mant fas atual  mant fas atual       nao avali
# ALUNO-8   promov fas bols      promov fas      promov fas  mant fas atual
# ALUNO-11       promov fas  mant fas atual  mant fas atual       nao avali
#
#          rec_equipe_1_resultado rec_equipe_2_resultado rec_equipe_3_resultado  \
# nome
# ALUNO-1                Positivo               Positivo                 Neutro
# ALUNO-3                Positivo               Positivo                 Neutro
# ALUNO-5                Positivo                 Neutro                 Neutro
# ALUNO-8                Positivo               Positivo               Positivo
# ALUNO-11               Positivo                 Neutro                 Neutro
#
#          rec_equipe_4_resultado  rec_equipe_1_resultado_encoded  \
# nome
# ALUNO-1                     NaN                             1.0
# ALUNO-3                     NaN                             1.0
# ALUNO-5                     NaN                             1.0
# ALUNO-8                  Neutro                             1.0
# ALUNO-11                    NaN                             1.0
#
#           rec_equipe_2_resultado_encoded  rec_equipe_3_resultado_encoded  \
# nome
# ALUNO-1                              1.0                             0.0
# ALUNO-3                              1.0                             0.0
# ALUNO-5                              0.0                             0.0
# ALUNO-8                              1.0                             1.0
# ALUNO-11                             0.0                             0.0
#
#           rec_equipe_4_resultado_encoded  rec_sintese
# nome
# ALUNO-1                              NaN          1.0
# ALUNO-3                              NaN          1.0
# ALUNO-5                              NaN          0.0
# ALUNO-8                              0.0          1.0
# ALUNO-11                             NaN          0.0

# %% [markdown]
# ### cria colunas `na_fase` e `diff_fase` comuns a todos os dataframes
#
# A coluna `na_fase` é calculada de acordo com as colunas `fase` e `fase_ideal`
#
# A diferença entre `fase` - `fase_ideal` irá dizer se o aluno está na fase correta (`diff_fase`). Também por

# %%
print(df_2020.columns)
print(df_2021.columns)
print(df_2022.columns)
# Out:
# Index(['instituicao_ensino_aluno', 'idade_aluno', 'anos_pm', 'fase_turma',
#        'ponto_virada', 'inde', 'inde_conceito', 'pedra', 'destaque_ieg',
#        'destaque_ida', 'destaque_ipv', 'iaa', 'ieg', 'ips', 'ida', 'ipp',
#        'ipv', 'ian', 'sexo', 'corraca', 'fase', 'bolsista_encoded',
#        'ponto_virada_encoded', 'pedra_encoded'],
#       dtype='object')
# Index(['fase', 'turma', 'instituicao_ensino_aluno', 'sinalizador_ingressante',
#        'pedra', 'inde', 'iaa', 'ieg', 'ips', 'ida', 'ipp', 'rec_equipe_1',
#        'rec_equipe_2', 'rec_equipe_3', 'rec_equipe_4', 'ponto_virada', 'ipv',
#        'ian', 'nivel_ideal', 'defasagem', 'sexo', 'corraca',
#        'bolsista_encoded', 'ponto_virada_encoded', 'pedra_encoded', 'anos_pm',
#        'fase_ideal'],
#       dtype='object')
# Index(['fase', 'turma', 'ano_ingresso', 'bolsista', 'inde', 'cg', 'cf', 'ct',
#        'pedra', 'destaque_ieg', 'destaque_ida', 'destaque_ipv', 'iaa', 'ieg',
#        'ips', 'ida', 'nota_port', 'nota_mat', 'nota_ing', 'qtd_aval', 'ipp',
#        'rec_ava_1', 'rec_ava_2', 'rec_ava_3', 'rec_ava_4', 'indicado_bolsa',
#        'ponto_virada', 'ipv', 'ian', 'nivel_ideal', 'sexo', 'corraca',
#        'bolsista_encoded', 'ponto_virada_encoded', 'pedra_encoded', 'anos_pm',
#        'fase_ideal'],
#       dtype='object')

# %%
df_2020[["fase", "idade_aluno"]].head()
# Out:
#          fase idade_aluno
# nome
# ALUNO-1     2          11
# ALUNO-3     3          12
# ALUNO-4     1          10
# ALUNO-5     2          10
# ALUNO-8     4          14

# %%
# Função para verificar se a idade está na fase correta
def verificar_fase_ideal(fase, idade):
    fase_idade_ideal = {
        0: (7, 8),
        1: (8, 9),
        2: (10, 11),
        3: (12, 13),
        4: (14, 14),
        5: (15, 15),
        6: (16, 16),
        7: (17, 17),
        8: (18, float("inf")),  # 18 anos ou mais
    }
    idade_min, idade_max = fase_idade_ideal.get(fase, (None, None))
    if idade_min is None or idade_max is None:
        return 0, None  # Caso a fase não esteja definida na tabela
    if idade_min <= idade <= idade_max:
        return 1, 0  # Está na fase correta
    else:
        # Calcular diferença de fase ideal
        fase_ideal = next(
            (
                f
                for f, (min_idade, max_idade) in fase_idade_ideal.items()
                if min_idade <= idade <= max_idade
            ),
            None,
        )
        diff_fase = fase - fase_ideal if fase_ideal is not None else None
        return 0, diff_fase

# %%
# Aplicar a verificação
df_2020["na_fase"], df_2020["diff_fase"] = zip(
    *df_2020.apply(
        lambda row: verificar_fase_ideal(int(row["fase"]), int(row["idade_aluno"])),
        axis=1,
    )
)

df_2020.head()
# Out:
#         instituicao_ensino_aluno idade_aluno anos_pm fase_turma ponto_virada  \
# nome
# ALUNO-1           Escola Pública          11       2         2H          Não
# ALUNO-3           Escola Pública          12       2         3H          Não
# ALUNO-4           Escola Pública          10       2         1D          Não
# ALUNO-5           Escola Pública          10       1         2M          Não
# ALUNO-8       Rede Decisão/União          14       3         4L          Sim
#
#                       inde inde_conceito     pedra  \
# nome
# ALUNO-1           7.883752             B  Ametista
# ALUNO-3  7.856389666666666             B  Ametista
# ALUNO-4           5.076252             D   Quartzo
# ALUNO-5           8.077085             B  Ametista
# ALUNO-8  8.381390666666666             B  Ametista
#
#                                               destaque_ieg  \
# nome
# ALUNO-1  Seu destaque em 2020: A sua boa entrega das li...
# ALUNO-3  Seu destaque em 2020: A sua boa entrega das li...
# ALUNO-4  Ponto a melhorar em 2021: Melhorar a sua entre...
# ALUNO-5  Seu destaque em 2020: A sua boa entrega das li...
# ALUNO-8  Seu destaque em 2020: A sua boa entrega das li...
#
#                                               destaque_ida  ...  \
# nome                                                        ...
# ALUNO-1  Ponto a melhorar em 2021: Empenhar-se mais nas...  ...
# ALUNO-3  Ponto a melhorar em 2021: Empenhar-se mais nas...  ...
# ALUNO-4  Ponto a melhorar em 2021: Empenhar-se mais nas...  ...
# ALUNO-5  Seu destaque em 2020: As suas boas notas na Pa...  ...
# ALUNO-8  Ponto a melhorar em 2021: Empenhar-se mais nas...  ...
#
#                        ipv ian sexo corraca fase bolsista_encoded  \
# nome
# ALUNO-1               7.75  10    F       R    2                0
# ALUNO-3  8.111113333333334  10    F       B    3                0
# ALUNO-4               7.75   5    M       R    1                0
# ALUNO-5           8.166665  10    M       R    2                0
# ALUNO-8            8.94445  10    F       R    4                1
#
#         ponto_virada_encoded pedra_encoded na_fase diff_fase
# nome
# ALUNO-1                    0             3       1         0
# ALUNO-3                    0             3       1         0
# ALUNO-4                    0             1       0        -1
# ALUNO-5                    0             3       1         0
# ALUNO-8                    1             3       1         0
#
# [5 rows x 26 columns]

# %%
df_2021["na_fase"] = df_2021.apply(
    lambda row: 1 if row["fase"] == row["fase_ideal"] else 0, axis=1
)
df_2021["diff_fase"] = df_2021.apply(
    lambda row: row["fase"] - row["fase_ideal"], axis=1
)


df_2021.head()
# Out:
#           fase turma instituicao_ensino_aluno sinalizador_ingressante  \
# nome
# ALUNO-1      2     G             Rede Decisão             Ingressante
# ALUNO-3      3     F           Escola Pública                Veterano
# ALUNO-5      2     L           Escola Pública                Veterano
# ALUNO-8      5     L             Rede Decisão                Veterano
# ALUNO-11     1     A             Rede Decisão                Veterano
#
#              pedra   inde  iaa   ieg  ips  ida  ...  defasagem sexo corraca  \
# nome                                            ...
# ALUNO-1   Ametista  7.319  7.5   6.3  6.9  8.8  ...       -1.0    F       R
# ALUNO-3   Ametista  7.021  7.1   6.9  6.3  5.6  ...        0.0    F       B
# ALUNO-5   Ametista  7.399  7.4   7.5  7.5  5.4  ...        0.0    M       R
# ALUNO-8    Topázio  8.269  8.8   8.6  7.5  7.1  ...        0.0    F       R
# ALUNO-11   Topázio  8.990  9.0  10.0  6.3  8.8  ...        0.0    M       R
#
#          bolsista_encoded ponto_virada_encoded pedra_encoded  anos_pm  \
# nome
# ALUNO-1                 1                    0             3      3.0
# ALUNO-3                 0                    0             3      3.0
# ALUNO-5                 0                    0             3      2.0
# ALUNO-8                 1                    0             4      4.0
# ALUNO-11                1                    1             4      1.0
#
#           fase_ideal na_fase  diff_fase
# nome
# ALUNO-1          3.0       0       -1.0
# ALUNO-3          3.0       1        0.0
# ALUNO-5          2.0       1        0.0
# ALUNO-8          5.0       1        0.0
# ALUNO-11         1.0       1        0.0
#
# [5 rows x 29 columns]

# %%
df_2022["na_fase"] = df_2022.apply(
    lambda row: 1 if row["fase"] == row["fase_ideal"] else 0, axis=1
)

df_2022["diff_fase"] = df_2022.apply(
    lambda row: row["fase"] - row["fase_ideal"], axis=1
)

df_2022.head()
# Out:
#          fase turma  ano_ingresso bolsista      inde     cg    cf    ct  \
# nome
# ALUNO-2     0     K        2022.0      Não  7.675509  245.0  66.0   6.0
# ALUNO-4     2     J        2022.0      Não  7.117065  451.0  69.0   3.0
# ALUNO-5     2     L        2019.0      Não  7.232336  415.0  61.0  12.0
# ALUNO-6     2     K        2022.0      Não  7.741669  221.0  35.0   2.0
# ALUNO-7     1     U        2022.0      Não  7.406743  357.0  93.0   7.0
#
#             pedra                                     destaque_ieg  ...  \
# nome                                                                ...
# ALUNO-2  Ametista  Destaque: A sua boa entrega das lições de casa.  ...
# ALUNO-4  Ametista  Destaque: A sua boa entrega das lições de casa.  ...
# ALUNO-5  Ametista  Destaque: A sua boa entrega das lições de casa.  ...
# ALUNO-6  Ametista  Destaque: A sua boa entrega das lições de casa.  ...
# ALUNO-7  Ametista  Destaque: A sua boa entrega das lições de casa.  ...
#
#                   nivel_ideal sexo  corraca  bolsista_encoded  \
# nome
# ALUNO-2  Fase 2 (5º e 6º ano)    F        B                 0
# ALUNO-4  Fase 3 (7º e 8º ano)    M        R                 0
# ALUNO-5  Fase 3 (7º e 8º ano)    M        R                 0
# ALUNO-6  Fase 2 (5º e 6º ano)    F        B                 0
# ALUNO-7  Fase 2 (5º e 6º ano)    M        B                 0
#
#          ponto_virada_encoded  pedra_encoded  anos_pm  fase_ideal  na_fase  \
# nome
# ALUNO-2                     0              3      0.0         2.0        0
# ALUNO-4                     0              3      0.0         3.0        0
# ALUNO-5                     0              3      3.0         3.0        0
# ALUNO-6                     0              3      0.0         2.0        1
# ALUNO-7                     0              3      0.0         2.0        0
#
#          diff_fase
# nome
# ALUNO-2       -2.0
# ALUNO-4       -1.0
# ALUNO-5       -1.0
# ALUNO-6        0.0
# ALUNO-7       -1.0
#
# [5 rows x 39 columns]

# %% [markdown]
# ### cria coluna `idade` comum a todos os dataframes com base na coluna `idade_aluno` do df_2020

# %%
# Step 1: Create a dictionary for student ages from df_2020
df_2020["idade"] = df_2020["idade_aluno"].astype(float)
ages_2020 = df_2020["idade"].to_dict()

df_2021["idade"] = 0
df_2022["idade"] = 0


df_2021["idade"] = df_2021.index.map(
    lambda x: (ages_2020[x] + 1) if x in ages_2020 else None
)

df_2022["idade"] = df_2022.index.map(
    lambda x: (ages_2020[x] + 2) if x in ages_2020 else None
)

# %%
print(df_2020["idade"].head(10))
print(df_2021["idade"].head(10))
print(df_2022["idade"].head(10))
# Out:
# nome
# ALUNO-1     11.0
# ALUNO-3     12.0
# ALUNO-4     10.0
# ALUNO-5     10.0
# ALUNO-8     14.0
# ALUNO-10    13.0
# ALUNO-11     8.0
# ALUNO-12    14.0
# ALUNO-14    11.0
# ALUNO-15    12.0
# Name: idade, dtype: float64
# nome
# ALUNO-1     12.0
# ALUNO-3     13.0
# ALUNO-5     11.0
# ALUNO-8     15.0
# ALUNO-11     9.0
# ALUNO-13     NaN
# ALUNO-17    14.0
# ALUNO-18    15.0
# ALUNO-19     NaN
# ALUNO-28    14.0
# Name: idade, dtype: float64
# nome
# ALUNO-2      NaN
# ALUNO-4     12.0
# ALUNO-5     12.0
# ALUNO-6      NaN
# ALUNO-7      NaN
# ALUNO-8     16.0
# ALUNO-9      NaN
# ALUNO-11    10.0
# ALUNO-16     NaN
# ALUNO-17    15.0
# Name: idade, dtype: float64

# %%
df_2021[["idade", "fase", "fase_ideal"]]
# Out:
#             idade  fase  fase_ideal
# nome
# ALUNO-1      12.0     2         3.0
# ALUNO-3      13.0     3         3.0
# ALUNO-5      11.0     2         2.0
# ALUNO-8      15.0     5         5.0
# ALUNO-11      9.0     1         1.0
# ...           ...   ...         ...
# ALUNO-1338   11.0     2         2.0
# ALUNO-1343   12.0     2         3.0
# ALUNO-1344   15.0     2         5.0
# ALUNO-1345    NaN     0         1.0
# ALUNO-1348   14.0     3         4.0
#
# [686 rows x 3 columns]

# %%
df_2021[df_2021["idade"].isnull()][["idade", "fase", "fase_ideal"]]
# Out:
#             idade  fase  fase_ideal
# nome
# ALUNO-13      NaN     0         1.0
# ALUNO-19      NaN     2         3.0
# ALUNO-29      NaN     3         5.0
# ALUNO-38      NaN     3         3.0
# ALUNO-40      NaN     5         6.0
# ...           ...   ...         ...
# ALUNO-1330    NaN     4         5.0
# ALUNO-1332    NaN     0         0.0
# ALUNO-1334    NaN     0         0.0
# ALUNO-1335    NaN     2         2.0
# ALUNO-1345    NaN     0         1.0
#
# [229 rows x 3 columns]

# %%
df_2021["fase_ideal"].isnull().sum()
# Out:
# np.int64(2)

# %%
# idade_fase_ideal = {i: (i - 7) // 2 for i in range(7, 13)}


def verificar_idade_ideal(fase):

    fase_idade_ideal = {
        0: (7, 8),
        1: (8, 9),
        2: (10, 11),
        3: (12, 13),
        4: (14, 14),
        5: (15, 15),
        6: (16, 16),
        7: (17, 17),
        8: (18, 18),  # 18 anos ou mais
    }
    if fase >= 0:
        idade = max(fase_idade_ideal[fase])
    else:
        idade = np.nan

    return idade

# %%
df = df_2021[df_2021["idade"].isnull()][["idade", "fase", "fase_ideal"]].copy()


df["idade"] = df.apply(lambda row: verificar_idade_ideal(row["fase_ideal"]), axis=1)

# df["idade"].isnull().sum()

for i in df.index:
    df_2021.loc[i, "idade"] = df.loc[i, "idade"]

df_2021["idade"].isnull().sum()
# Out:
# np.int64(2)

# %%
df = df_2022[df_2022["idade"].isnull()][["idade", "fase", "fase_ideal"]].copy()


df["idade"] = df.apply(lambda row: verificar_idade_ideal(row["fase_ideal"]), axis=1)


for i in df.index:
    df_2022.loc[i, "idade"] = df.loc[i, "idade"]

df_2022["idade"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### cria coluna `sexo_encoded`

# %%
df_2020["sexo_encoded"] = df_2020["sexo"].map({"F": 1, "M": 0})
df_2021["sexo_encoded"] = df_2021["sexo"].map({"F": 1, "M": 0})
df_2022["sexo_encoded"] = df_2022["sexo"].map({"F": 1, "M": 0})

# %% [markdown]
# ## 1.3 Dataset por ano após pré-processamento

# %%
destaque_2022.columns
# Out:
# Index(['destaque_ieg', 'destaque_ida', 'destaque_ipv',
#        'destaque_ieg_resultado', 'destaque_ida_resultado',
#        'destaque_ipv_resultado', 'destaque_ieg_resultado_encoded',
#        'destaque_ida_resultado_encoded', 'destaque_ipv_resultado_encoded'],
#       dtype='object')

# %%
df_2020_preproc = df_2020.join(
    destaque_2020.drop(columns=["destaque_ida", "destaque_ipv", "destaque_ieg"])
).copy()
df_2022_preproc = df_2022.join(
    destaque_2022.drop(columns=["destaque_ida", "destaque_ipv", "destaque_ieg"])
).copy()

# %%
df_2021_preproc = df_2021.join(
    rec_equipe_2021.drop(
        columns=["rec_equipe_1", "rec_equipe_2", "rec_equipe_3", "rec_equipe_4"]
    )
).copy()
df_2022_preproc = df_2022_preproc.join(
    rec_ava_2022.drop(columns=["rec_ava_1", "rec_ava_2", "rec_ava_3", "rec_ava_4"])
).copy()

# %%
df_2020_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 703 entries, ALUNO-1 to ALUNO-1348
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   instituicao_ensino_aluno        703 non-null    object
#  1   idade_aluno                     703 non-null    object
#  2   anos_pm                         703 non-null    object
#  3   fase_turma                      703 non-null    object
#  4   ponto_virada                    701 non-null    object
#  5   inde                            703 non-null    object
#  6   inde_conceito                   703 non-null    object
#  7   pedra                           703 non-null    object
#  8   destaque_ieg                    703 non-null    object
#  9   destaque_ida                    703 non-null    object
#  10  destaque_ipv                    703 non-null    object
#  11  iaa                             703 non-null    object
#  12  ieg                             703 non-null    object
#  13  ips                             703 non-null    object
#  14  ida                             703 non-null    object
#  15  ipp                             703 non-null    object
#  16  ipv                             703 non-null    object
#  17  ian                             703 non-null    object
#  18  sexo                            702 non-null    object
#  19  corraca                         702 non-null    object
#  20  fase                            703 non-null    int64
#  21  bolsista_encoded                703 non-null    int64
#  22  ponto_virada_encoded            703 non-null    int64
#  23  pedra_encoded                   703 non-null    int64
#  24  na_fase                         703 non-null    int64
#  25  diff_fase                       703 non-null    int64
#  26  idade                           703 non-null    float64
#  27  sexo_encoded                    702 non-null    float64
#  28  destaque_ieg_resultado          703 non-null    object
#  29  destaque_ida_resultado          703 non-null    object
#  30  destaque_ipv_resultado          703 non-null    object
#  31  destaque_ieg_resultado_encoded  703 non-null    int64
#  32  destaque_ida_resultado_encoded  703 non-null    int64
#  33  destaque_ipv_resultado_encoded  703 non-null    int64
# dtypes: float64(2), int64(9), object(23)
# memory usage: 208.4+ KB

# %%
df_2021_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 686 entries, ALUNO-1 to ALUNO-1348
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   fase                            686 non-null    int64
#  1   turma                           686 non-null    object
#  2   instituicao_ensino_aluno        686 non-null    object
#  3   sinalizador_ingressante         686 non-null    object
#  4   pedra                           686 non-null    object
#  5   inde                            686 non-null    object
#  6   iaa                             686 non-null    float64
#  7   ieg                             686 non-null    float64
#  8   ips                             686 non-null    float64
#  9   ida                             686 non-null    float64
#  10  ipp                             686 non-null    float64
#  11  rec_equipe_1                    686 non-null    object
#  12  rec_equipe_2                    686 non-null    object
#  13  rec_equipe_3                    686 non-null    object
#  14  rec_equipe_4                    686 non-null    object
#  15  ponto_virada                    686 non-null    object
#  16  ipv                             686 non-null    float64
#  17  ian                             686 non-null    float64
#  18  nivel_ideal                     686 non-null    object
#  19  defasagem                       686 non-null    float64
#  20  sexo                            685 non-null    object
#  21  corraca                         685 non-null    object
#  22  bolsista_encoded                686 non-null    int64
#  23  ponto_virada_encoded            686 non-null    int64
#  24  pedra_encoded                   686 non-null    int64
#  25  anos_pm                         686 non-null    float64
#  26  fase_ideal                      684 non-null    float64
#  27  na_fase                         686 non-null    int64
#  28  diff_fase                       684 non-null    float64
#  29  idade                           684 non-null    float64
#  30  sexo_encoded                    685 non-null    float64
#  31  rec_equipe_1_resultado          673 non-null    object
#  32  rec_equipe_2_resultado          668 non-null    object
#  33  rec_equipe_3_resultado          543 non-null    object
#  34  rec_equipe_4_resultado          144 non-null    object
#  35  rec_equipe_1_resultado_encoded  673 non-null    float64
#  36  rec_equipe_2_resultado_encoded  668 non-null    float64
#  37  rec_equipe_3_resultado_encoded  543 non-null    float64
#  38  rec_equipe_4_resultado_encoded  144 non-null    float64
#  39  rec_sintese                     683 non-null    float64
# dtypes: float64(18), int64(5), object(17)
# memory usage: 235.9+ KB

# %%
df_2022_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 862 entries, ALUNO-2 to ALUNO-1349
# Data columns (total 56 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   fase                            862 non-null    int64
#  1   turma                           862 non-null    object
#  2   ano_ingresso                    862 non-null    float64
#  3   bolsista                        862 non-null    object
#  4   inde                            862 non-null    float64
#  5   cg                              862 non-null    float64
#  6   cf                              862 non-null    float64
#  7   ct                              862 non-null    float64
#  8   pedra                           862 non-null    object
#  9   destaque_ieg                    862 non-null    object
#  10  destaque_ida                    862 non-null    object
#  11  destaque_ipv                    862 non-null    object
#  12  iaa                             862 non-null    float64
#  13  ieg                             862 non-null    float64
#  14  ips                             862 non-null    float64
#  15  ida                             862 non-null    float64
#  16  nota_port                       860 non-null    float64
#  17  nota_mat                        860 non-null    float64
#  18  nota_ing                        285 non-null    float64
#  19  qtd_aval                        862 non-null    float64
#  20  ipp                             862 non-null    float64
#  21  rec_ava_1                       862 non-null    object
#  22  rec_ava_2                       862 non-null    object
#  23  rec_ava_3                       626 non-null    object
#  24  rec_ava_4                       285 non-null    object
#  25  indicado_bolsa                  862 non-null    object
#  26  ponto_virada                    862 non-null    object
#  27  ipv                             862 non-null    float64
#  28  ian                             862 non-null    float64
#  29  nivel_ideal                     862 non-null    object
#  30  sexo                            861 non-null    object
#  31  corraca                         861 non-null    object
#  32  bolsista_encoded                862 non-null    int64
#  33  ponto_virada_encoded            862 non-null    int64
#  34  pedra_encoded                   862 non-null    int64
#  35  anos_pm                         862 non-null    float64
#  36  fase_ideal                      862 non-null    float64
#  37  na_fase                         862 non-null    int64
#  38  diff_fase                       862 non-null    float64
#  39  idade                           862 non-null    float64
#  40  sexo_encoded                    861 non-null    float64
#  41  destaque_ieg_resultado          862 non-null    object
#  42  destaque_ida_resultado          862 non-null    object
#  43  destaque_ipv_resultado          862 non-null    object
#  44  destaque_ieg_resultado_encoded  862 non-null    int64
#  45  destaque_ida_resultado_encoded  862 non-null    int64
#  46  destaque_ipv_resultado_encoded  862 non-null    int64
#  47  rec_ava_1_resultado             860 non-null    object
#  48  rec_ava_2_resultado             860 non-null    object
#  49  rec_ava_3_resultado             626 non-null    object
#  50  rec_ava_4_resultado             285 non-null    object
#  51  rec_ava_1_resultado_encoded     860 non-null    float64
#  52  rec_ava_2_resultado_encoded     860 non-null    float64
#  53  rec_ava_3_resultado_encoded     626 non-null    float64
#  54  rec_ava_4_resultado_encoded     285 non-null    float64
#  55  rec_sintese                     860 non-null    float64
# dtypes: float64(26), int64(8), object(22)
# memory usage: 416.1+ KB

# %%
# Escreve em arquivo
df_2020_preproc.to_csv("data/df_2020_preproc.csv")
df_2021_preproc.to_csv("data/df_2021_preproc.csv")
df_2022_preproc.to_csv("data/df_2022_preproc.csv")

# %% [markdown]
# ### Seleciona colunas para modelagem e análise exploratória

# %%
df_2020_preproc.columns
# Out:
# Index(['instituicao_ensino_aluno', 'idade_aluno', 'anos_pm', 'fase_turma',
#        'ponto_virada', 'inde', 'inde_conceito', 'pedra', 'destaque_ieg',
#        'destaque_ida', 'destaque_ipv', 'iaa', 'ieg', 'ips', 'ida', 'ipp',
#        'ipv', 'ian', 'sexo', 'corraca', 'fase', 'bolsista_encoded',
#        'ponto_virada_encoded', 'pedra_encoded', 'na_fase', 'diff_fase',
#        'idade', 'sexo_encoded', 'destaque_ieg_resultado',
#        'destaque_ida_resultado', 'destaque_ipv_resultado',
#        'destaque_ieg_resultado_encoded', 'destaque_ida_resultado_encoded',
#        'destaque_ipv_resultado_encoded'],
#       dtype='object')

# %%
# seleciona colunas de interesse
df_2020_preproc_select = df_2020_preproc[
    [
        "idade",
        "anos_pm",
        "inde",
        "pedra",
        "iaa",
        "ieg",
        "ips",
        "ida",
        "ipp",
        "ipv",
        "ian",
        "sexo",
        "corraca",
        "fase",
        "bolsista_encoded",
        "ponto_virada_encoded",
        "pedra_encoded",
        "destaque_ieg_resultado",
        "destaque_ida_resultado",
        "destaque_ipv_resultado",
        "destaque_ieg_resultado_encoded",
        "destaque_ida_resultado_encoded",
        "destaque_ipv_resultado_encoded",
    ]
].copy()
df_2020_preproc_select.head()
# Out:
#          idade anos_pm               inde     pedra                iaa  ieg  \
# nome
# ALUNO-1   11.0       2           7.883752  Ametista  8.500020000000001  8.7
# ALUNO-3   12.0       2  7.856389666666666  Ametista            7.91667  8.9
# ALUNO-4   10.0       2           5.076252   Quartzo  8.000020000000001  4.1
# ALUNO-5   10.0       1           8.077085  Ametista            7.50002    8
# ALUNO-8   14.0       3  8.381390666666666  Ametista            8.33334  9.9
#
#            ips                ida                ipp                ipv  ...  \
# nome                                                                     ...
# ALUNO-1    7.5                  7             5.9375               7.75  ...
# ALUNO-3    7.5                5.5              8.125  8.111113333333334  ...
# ALUNO-4  6.875                  0             7.1875               7.75  ...
# ALUNO-5    7.5                7.5             8.4375           8.166665  ...
# ALUNO-8  4.375  7.333333333333333  8.749999999999998            8.94445  ...
#
#         fase bolsista_encoded ponto_virada_encoded  pedra_encoded  \
# nome
# ALUNO-1    2                0                    0              3
# ALUNO-3    3                0                    0              3
# ALUNO-4    1                0                    0              1
# ALUNO-5    2                0                    0              3
# ALUNO-8    4                1                    1              3
#
#          destaque_ieg_resultado  destaque_ida_resultado  \
# nome
# ALUNO-1                Positivo                Negativo
# ALUNO-3                Positivo                Negativo
# ALUNO-4                Negativo                Negativo
# ALUNO-5                Positivo                Positivo
# ALUNO-8                Positivo                Negativo
#
#          destaque_ipv_resultado destaque_ieg_resultado_encoded  \
# nome
# ALUNO-1                Positivo                              1
# ALUNO-3                Positivo                              1
# ALUNO-4                Negativo                             -1
# ALUNO-5                Positivo                              1
# ALUNO-8                Positivo                              1
#
#         destaque_ida_resultado_encoded destaque_ipv_resultado_encoded
# nome
# ALUNO-1                             -1                              1
# ALUNO-3                             -1                              1
# ALUNO-4                             -1                             -1
# ALUNO-5                              1                              1
# ALUNO-8                             -1                              1
#
# [5 rows x 23 columns]

# %%
df_2021_preproc.columns
# Out:
# Index(['fase', 'turma', 'instituicao_ensino_aluno', 'sinalizador_ingressante',
#        'pedra', 'inde', 'iaa', 'ieg', 'ips', 'ida', 'ipp', 'rec_equipe_1',
#        'rec_equipe_2', 'rec_equipe_3', 'rec_equipe_4', 'ponto_virada', 'ipv',
#        'ian', 'nivel_ideal', 'defasagem', 'sexo', 'corraca',
#        'bolsista_encoded', 'ponto_virada_encoded', 'pedra_encoded', 'anos_pm',
#        'fase_ideal', 'na_fase', 'diff_fase', 'idade', 'sexo_encoded',
#        'rec_equipe_1_resultado', 'rec_equipe_2_resultado',
#        'rec_equipe_3_resultado', 'rec_equipe_4_resultado',
#        'rec_equipe_1_resultado_encoded', 'rec_equipe_2_resultado_encoded',
#        'rec_equipe_3_resultado_encoded', 'rec_equipe_4_resultado_encoded',
#        'rec_sintese'],
#       dtype='object')

# %%
df_2021_preproc_select = df_2021_preproc[
    [
        "idade",
        "anos_pm",
        "fase",
        "sinalizador_ingressante",
        "pedra",
        "inde",
        "iaa",
        "ieg",
        "ips",
        "ida",
        "ipp",
        "ipv",
        "ian",
        "defasagem",
        "sexo",
        "corraca",
        "bolsista_encoded",
        "ponto_virada_encoded",
        "pedra_encoded",
        "fase_ideal",
        "rec_equipe_1_resultado",
        "rec_equipe_2_resultado",
        "rec_equipe_3_resultado",
        "rec_equipe_4_resultado",
        "rec_equipe_1_resultado_encoded",
        "rec_equipe_2_resultado_encoded",
        "rec_equipe_3_resultado_encoded",
        "rec_equipe_4_resultado_encoded",
        "rec_sintese",
    ]
]

df_2021_preproc_select.head()
# Out:
#           idade  anos_pm  fase sinalizador_ingressante     pedra   inde  iaa  \
# nome
# ALUNO-1    12.0      3.0     2             Ingressante  Ametista  7.319  7.5
# ALUNO-3    13.0      3.0     3                Veterano  Ametista  7.021  7.1
# ALUNO-5    11.0      2.0     2                Veterano  Ametista  7.399  7.4
# ALUNO-8    15.0      4.0     5                Veterano   Topázio  8.269  8.8
# ALUNO-11    9.0      1.0     1                Veterano   Topázio  8.990  9.0
#
#            ieg  ips  ida  ...  fase_ideal  rec_equipe_1_resultado  \
# nome                      ...
# ALUNO-1    6.3  6.9  8.8  ...         3.0                Positivo
# ALUNO-3    6.9  6.3  5.6  ...         3.0                Positivo
# ALUNO-5    7.5  7.5  5.4  ...         2.0                Positivo
# ALUNO-8    8.6  7.5  7.1  ...         5.0                Positivo
# ALUNO-11  10.0  6.3  8.8  ...         1.0                Positivo
#
#           rec_equipe_2_resultado  rec_equipe_3_resultado  \
# nome
# ALUNO-1                 Positivo                  Neutro
# ALUNO-3                 Positivo                  Neutro
# ALUNO-5                   Neutro                  Neutro
# ALUNO-8                 Positivo                Positivo
# ALUNO-11                  Neutro                  Neutro
#
#          rec_equipe_4_resultado rec_equipe_1_resultado_encoded  \
# nome
# ALUNO-1                     NaN                            1.0
# ALUNO-3                     NaN                            1.0
# ALUNO-5                     NaN                            1.0
# ALUNO-8                  Neutro                            1.0
# ALUNO-11                    NaN                            1.0
#
#           rec_equipe_2_resultado_encoded  rec_equipe_3_resultado_encoded  \
# nome
# ALUNO-1                              1.0                             0.0
# ALUNO-3                              1.0                             0.0
# ALUNO-5                              0.0                             0.0
# ALUNO-8                              1.0                             1.0
# ALUNO-11                             0.0                             0.0
#
#           rec_equipe_4_resultado_encoded  rec_sintese
# nome
# ALUNO-1                              NaN          1.0
# ALUNO-3                              NaN          1.0
# ALUNO-5                              NaN          0.0
# ALUNO-8                              0.0          1.0
# ALUNO-11                             NaN          0.0
#
# [5 rows x 29 columns]

# %%
df_2022_preproc.columns
# Out:
# Index(['fase', 'turma', 'ano_ingresso', 'bolsista', 'inde', 'cg', 'cf', 'ct',
#        'pedra', 'destaque_ieg', 'destaque_ida', 'destaque_ipv', 'iaa', 'ieg',
#        'ips', 'ida', 'nota_port', 'nota_mat', 'nota_ing', 'qtd_aval', 'ipp',
#        'rec_ava_1', 'rec_ava_2', 'rec_ava_3', 'rec_ava_4', 'indicado_bolsa',
#        'ponto_virada', 'ipv', 'ian', 'nivel_ideal', 'sexo', 'corraca',
#        'bolsista_encoded', 'ponto_virada_encoded', 'pedra_encoded', 'anos_pm',
#        'fase_ideal', 'na_fase', 'diff_fase', 'idade', 'sexo_encoded',
#        'destaque_ieg_resultado', 'destaque_ida_resultado',
#        'destaque_ipv_resultado', 'destaque_ieg_resultado_encoded',
#        'destaque_ida_resultado_encoded', 'destaque_ipv_resultado_encoded',
#        'rec_ava_1_resultado', 'rec_ava_2_resultado', 'rec_ava_3_resultado',
#        'rec_ava_4_resultado', 'rec_ava_1_resultado_encoded',
#        'rec_ava_2_resultado_encoded', 'rec_ava_3_resultado_encoded',
#        'rec_ava_4_resultado_encoded', 'rec_sintese'],
#       dtype='object')

# %%
df_2022_preproc_select = df_2022_preproc[
    [
        "idade",
        "fase",
        "turma",
        "ano_ingresso",
        "bolsista",
        "inde",
        "cg",
        "cf",
        "ct",
        "iaa",
        "ieg",
        "ips",
        "ida",
        "nota_port",
        "nota_mat",
        "nota_ing",
        "qtd_aval",
        "ipp",
        "indicado_bolsa",
        "ipv",
        "ian",
        "nivel_ideal",
        "sexo",
        "corraca",
        "bolsista_encoded",
        "ponto_virada_encoded",
        "pedra",
        "pedra_encoded",
        "anos_pm",
        "fase_ideal",
        "destaque_ieg_resultado",
        "destaque_ida_resultado",
        "destaque_ipv_resultado",
        "destaque_ieg_resultado_encoded",
        "destaque_ida_resultado_encoded",
        "destaque_ipv_resultado_encoded",
        "rec_ava_1_resultado",
        "rec_ava_2_resultado",
        "rec_ava_3_resultado",
        "rec_ava_4_resultado",
        "rec_ava_1_resultado_encoded",
        "rec_ava_2_resultado_encoded",
        "rec_ava_3_resultado_encoded",
        "rec_ava_4_resultado_encoded",
        "rec_sintese",
    ]
]
df_2022_preproc_select.head()
# Out:
#          idade  fase turma  ano_ingresso bolsista      inde     cg    cf  \
# nome
# ALUNO-2   11.0     0     K        2022.0      Não  7.675509  245.0  66.0
# ALUNO-4   12.0     2     J        2022.0      Não  7.117065  451.0  69.0
# ALUNO-5   12.0     2     L        2019.0      Não  7.232336  415.0  61.0
# ALUNO-6   11.0     2     K        2022.0      Não  7.741669  221.0  35.0
# ALUNO-7   11.0     1     U        2022.0      Não  7.406743  357.0  93.0
#
#            ct       iaa  ...  destaque_ipv_resultado_encoded  \
# nome                     ...
# ALUNO-2   6.0  10.00002  ...                               1
# ALUNO-4   3.0  10.00002  ...                               1
# ALUNO-5  12.0   6.41668  ...                               1
# ALUNO-6   2.0   9.00002  ...                               1
# ALUNO-7   7.0  10.00002  ...                               1
#
#          rec_ava_1_resultado  rec_ava_2_resultado  rec_ava_3_resultado  \
# nome
# ALUNO-2             Positivo               Neutro                  NaN
# ALUNO-4             Positivo               Neutro             Positivo
# ALUNO-5               Neutro             Positivo               Neutro
# ALUNO-6               Neutro             Positivo               Neutro
# ALUNO-7             Positivo             Positivo                  NaN
#
#          rec_ava_4_resultado  rec_ava_1_resultado_encoded  \
# nome
# ALUNO-2                  NaN                          1.0
# ALUNO-4                  NaN                          1.0
# ALUNO-5                  NaN                          0.0
# ALUNO-6                  NaN                          0.0
# ALUNO-7                  NaN                          1.0
#
#          rec_ava_2_resultado_encoded  rec_ava_3_resultado_encoded  \
# nome
# ALUNO-2                          0.0                          NaN
# ALUNO-4                          0.0                          1.0
# ALUNO-5                          1.0                          0.0
# ALUNO-6                          1.0                          0.0
# ALUNO-7                          1.0                          NaN
#
#         rec_ava_4_resultado_encoded  rec_sintese
# nome
# ALUNO-2                         NaN          1.0
# ALUNO-4                         NaN          1.0
# ALUNO-5                         NaN          0.0
# ALUNO-6                         NaN          0.0
# ALUNO-7                         NaN          1.0
#
# [5 rows x 45 columns]

# %%
# Escreve em arquivo
df_2020_preproc_select.to_csv("data/df_2020_preproc_select.csv")
df_2021_preproc_select.to_csv("data/df_2021_preproc_select.csv")
df_2022_preproc_select.to_csv("data/df_2022_preproc_select.csv")

# %% [markdown]
# ### Empilhar dados pré-processados
#
# O empilhamento é necessário para realizar a análise da evolução das unidades (alunos) ao longo do tempo

# %%
df_2020["ano"] = 2020
df_2021["ano"] = 2021
df_2022["ano"] = 2022

# Identifying common columns between the datasets
common_columns = list(
    set(df_2020.columns) & set(df_2021.columns) & set(df_2022.columns)
)



# Concatenating the datasets based on the common columns



df_pooled = pd.concat(
    [df_2020[common_columns], df_2021[common_columns], df_2022[common_columns]], axis=0
)

# %%
df_pooled.head()
# Out:
#                        ida  diff_fase  ponto_virada_encoded anos_pm  \
# nome
# ALUNO-1                  7        0.0                     0       2
# ALUNO-3                5.5        0.0                     0       2
# ALUNO-4                  0       -1.0                     0       2
# ALUNO-5                7.5        0.0                     0       1
# ALUNO-8  7.333333333333333        0.0                     1       3
#
#          bolsista_encoded                ipv corraca ponto_virada ian  \
# nome
# ALUNO-1                 0               7.75       R          Não  10
# ALUNO-3                 0  8.111113333333334       B          Não  10
# ALUNO-4                 0               7.75       R          Não   5
# ALUNO-5                 0           8.166665       R          Não  10
# ALUNO-8                 1            8.94445       R          Sim  10
#
#             pedra  ...    ips  ieg                ipp idade sexo_encoded  \
# nome               ...
# ALUNO-1  Ametista  ...    7.5  8.7             5.9375  11.0          1.0
# ALUNO-3  Ametista  ...    7.5  8.9              8.125  12.0          1.0
# ALUNO-4   Quartzo  ...  6.875  4.1             7.1875  10.0          0.0
# ALUNO-5  Ametista  ...    7.5    8             8.4375  10.0          0.0
# ALUNO-8  Ametista  ...  4.375  9.9  8.749999999999998  14.0          1.0
#
#          fase               inde  sexo na_fase   ano
# nome
# ALUNO-1     2           7.883752     F       1  2020
# ALUNO-3     3  7.856389666666666     F       1  2020
# ALUNO-4     1           5.076252     M       0  2020
# ALUNO-5     2           8.077085     M       1  2020
# ALUNO-8     4  8.381390666666666     F       1  2020
#
# [5 rows x 22 columns]

# %%
df_ranking = df_2022[["cg", "cf", "ct"]].copy()
df_ranking.head()
# Out:
#             cg    cf    ct
# nome
# ALUNO-2  245.0  66.0   6.0
# ALUNO-4  451.0  69.0   3.0
# ALUNO-5  415.0  61.0  12.0
# ALUNO-6  221.0  35.0   2.0
# ALUNO-7  357.0  93.0   7.0

# %%
common_students = df_ranking.index.intersection(df_pooled.index)
common_students
# Out:
# Index(['ALUNO-2', 'ALUNO-4', 'ALUNO-5', 'ALUNO-6', 'ALUNO-7', 'ALUNO-8',
#        'ALUNO-9', 'ALUNO-11', 'ALUNO-16', 'ALUNO-17',
#        ...
#        'ALUNO-1334', 'ALUNO-1335', 'ALUNO-1337', 'ALUNO-1338', 'ALUNO-1340',
#        'ALUNO-1342', 'ALUNO-1343', 'ALUNO-1346', 'ALUNO-1348', 'ALUNO-1349'],
#       dtype='object', name='nome', length=862)

# %%
df_pooled_ranking = df_pooled.loc[common_students].join(df_ranking)

# %%
df_pooled_ranking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1646 entries, ALUNO-2 to ALUNO-1349
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ida                   1646 non-null   object
#  1   diff_fase             1646 non-null   float64
#  2   ponto_virada_encoded  1646 non-null   int64
#  3   anos_pm               1646 non-null   object
#  4   bolsista_encoded      1646 non-null   int64
#  5   ipv                   1646 non-null   object
#  6   corraca               1643 non-null   object
#  7   ponto_virada          1646 non-null   object
#  8   ian                   1646 non-null   object
#  9   pedra                 1646 non-null   object
#  10  pedra_encoded         1646 non-null   int64
#  11  iaa                   1646 non-null   object
#  12  ips                   1646 non-null   object
#  13  ieg                   1646 non-null   object
#  14  ipp                   1646 non-null   object
#  15  idade                 1646 non-null   float64
#  16  sexo_encoded          1643 non-null   float64
#  17  fase                  1646 non-null   int64
#  18  inde                  1646 non-null   object
#  19  sexo                  1643 non-null   object
#  20  na_fase               1646 non-null   int64
#  21  ano                   1646 non-null   int64
#  22  cg                    1646 non-null   float64
#  23  cf                    1646 non-null   float64
#  24  ct                    1646 non-null   float64
# dtypes: float64(6), int64(6), object(13)
# memory usage: 334.3+ KB

# %%
# select only columns of type object
df_pooled_ranking.select_dtypes(include=["object"]).columns
# Out:
# Index(['ida', 'anos_pm', 'ipv', 'corraca', 'ponto_virada', 'ian', 'pedra',
#        'iaa', 'ips', 'ieg', 'ipp', 'inde', 'sexo'],
#       dtype='object')

# %%
df_pooled_ranking.select_dtypes(include=["object"]).columns
# Out:
# Index(['ida', 'anos_pm', 'ipv', 'corraca', 'ponto_virada', 'ian', 'pedra',
#        'iaa', 'ips', 'ieg', 'ipp', 'inde', 'sexo'],
#       dtype='object')

# %%
# convert to float and fill missing values with np.nan
numeric_columns = ["ips", "ida", "iaa", "inde", "ieg", "ipp", "ian", "ipv", "anos_pm"]

df_pooled_ranking[numeric_columns] = (
    df_pooled_ranking[numeric_columns]
    .apply(pd.to_numeric, errors="coerce")
    .fillna(np.nan)
)
df_pooled[numeric_columns] = (
    df_pooled[numeric_columns].apply(pd.to_numeric, errors="coerce").fillna(np.nan)
)

# %%
print(df_pooled_ranking.info())
print(df_pooled.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1646 entries, ALUNO-2 to ALUNO-1349
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ida                   1646 non-null   float64
#  1   diff_fase             1646 non-null   float64
#  2   ponto_virada_encoded  1646 non-null   int64
#  3   anos_pm               1646 non-null   float64
#  4   bolsista_encoded      1646 non-null   int64
#  5   ipv                   1646 non-null   float64
#  6   corraca               1643 non-null   object
#  7   ponto_virada          1646 non-null   object
#  8   ian                   1646 non-null   float64
#  9   pedra                 1646 non-null   object
#  10  pedra_encoded         1646 non-null   int64
#  11  iaa                   1646 non-null   float64
#  12  ips                   1646 non-null   float64
#  13  ieg                   1646 non-null   float64
#  14  ipp                   1646 non-null   float64
#  15  idade                 1646 non-null   float64
#  16  sexo_encoded          1643 non-null   float64
#  17  fase                  1646 non-null   int64
#  18  inde                  1646 non-null   float64
#  19  sexo                  1643 non-null   object
#  20  na_fase               1646 non-null   int64
#  21  ano                   1646 non-null   int64
#  22  cg                    1646 non-null   float64
#  23  cf                    1646 non-null   float64
#  24  ct                    1646 non-null   float64
# dtypes: float64(15), int64(6), object(4)
# memory usage: 334.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 2251 entries, ALUNO-1 to ALUNO-1349
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ida                   2251 non-null   float64
#  1   diff_fase             2249 non-null   float64
#  2   ponto_virada_encoded  2251 non-null   int64
#  3   anos_pm               2251 non-null   float64
#  4   bolsista_encoded      2251 non-null   int64
#  5   ipv                   2251 non-null   float64
#  6   corraca               2248 non-null   object
#  7   ponto_virada          2249 non-null   object
#  8   ian                   2251 non-null   float64
#  9   pedra                 2251 non-null   object
#  10  pedra_encoded         2251 non-null   int64
#  11  iaa                   2251 non-null   float64
#  12  ips                   2251 non-null   float64
#  13  ieg                   2251 non-null   float64
#  14  ipp                   2251 non-null   float64
#  15  idade                 2249 non-null   float64
#  16  sexo_encoded          2248 non-null   float64
#  17  fase                  2251 non-null   int64
#  18  inde                  2251 non-null   float64
#  19  sexo                  2248 non-null   object
#  20  na_fase               2251 non-null   int64
#  21  ano                   2251 non-null   int64
# dtypes: float64(12), int64(6), object(4)
# memory usage: 469.0+ KB
# None

# %%
df_pooled_ranking.isnull().sum()
# Out:
# ida                     0
# diff_fase               0
# ponto_virada_encoded    0
# anos_pm                 0
# bolsista_encoded        0
# ipv                     0
# corraca                 3
# ponto_virada            0
# ian                     0
# pedra                   0
# pedra_encoded           0
# iaa                     0
# ips                     0
# ieg                     0
# ipp                     0
# idade                   0
# sexo_encoded            3
# fase                    0
# inde                    0
# sexo                    3
# na_fase                 0
# ano                     0
# cg                      0
# cf                      0
# ct                      0
# dtype: int64

# %%
# Fill missing values with mode
df_pooled_ranking["sexo"].fillna(df_pooled_ranking["sexo"].mode()[0], inplace=True)
df_pooled_ranking["sexo_encoded"].fillna(
    df_pooled_ranking["sexo_encoded"].mode()[0], inplace=True
)
df_pooled_ranking["corraca"].fillna(df_pooled["corraca"].mode()[0], inplace=True)

df_pooled_ranking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1646 entries, ALUNO-2 to ALUNO-1349
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ida                   1646 non-null   float64
#  1   diff_fase             1646 non-null   float64
#  2   ponto_virada_encoded  1646 non-null   int64
#  3   anos_pm               1646 non-null   float64
#  4   bolsista_encoded      1646 non-null   int64
#  5   ipv                   1646 non-null   float64
#  6   corraca               1646 non-null   object
#  7   ponto_virada          1646 non-null   object
#  8   ian                   1646 non-null   float64
#  9   pedra                 1646 non-null   object
#  10  pedra_encoded         1646 non-null   int64
#  11  iaa                   1646 non-null   float64
#  12  ips                   1646 non-null   float64
#  13  ieg                   1646 non-null   float64
#  14  ipp                   1646 non-null   float64
#  15  idade                 1646 non-null   float64
#  16  sexo_encoded          1646 non-null   float64
#  17  fase                  1646 non-null   int64
#  18  inde                  1646 non-null   float64
#  19  sexo                  1646 non-null   object
#  20  na_fase               1646 non-null   int64
#  21  ano                   1646 non-null   int64
#  22  cg                    1646 non-null   float64
#  23  cf                    1646 non-null   float64
#  24  ct                    1646 non-null   float64
# dtypes: float64(15), int64(6), object(4)
# memory usage: 334.3+ KB
# C:\Users\carlo.000\AppData\Local\Temp\ipykernel_6088\454535677.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_pooled_ranking["sexo"].fillna(df_pooled_ranking["sexo"].mode()[0], inplace=True)
# C:\Users\carlo.000\AppData\Local\Temp\ipykernel_6088\454535677.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_pooled_ranking["sexo_encoded"].fillna(
# C:\Users\carlo.000\AppData\Local\Temp\ipykernel_6088\454535677.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_pooled_ranking["corraca"].fillna(df_pooled["corraca"].mode()[0], inplace=True)

# %%
df_pooled.isnull().sum()
# Out:
# ida                     0
# diff_fase               2
# ponto_virada_encoded    0
# anos_pm                 0
# bolsista_encoded        0
# ipv                     0
# corraca                 3
# ponto_virada            2
# ian                     0
# pedra                   0
# pedra_encoded           0
# iaa                     0
# ips                     0
# ieg                     0
# ipp                     0
# idade                   2
# sexo_encoded            3
# fase                    0
# inde                    0
# sexo                    3
# na_fase                 0
# ano                     0
# dtype: int64

# %%
# Escreve em arquivo
df_pooled.to_csv("data/df_pooled_common.csv")
df_pooled_ranking.to_csv("data/df_pooled_ranking.csv")

# %%
df_pooled_ranking.sort_values(by="cg")
# Out:
#                  ida  diff_fase  ponto_virada_encoded  anos_pm  \
# nome
# ALUNO-75    8.500000        1.0                     1      2.0
# ALUNO-75    8.500000        2.0                     1      3.0
# ALUNO-75    9.000000        1.0                     1      1.0
# ALUNO-916   7.800000        0.0                     1      4.0
# ALUNO-916   7.000000        0.0                     1      3.0
# ...              ...        ...                   ...      ...
# ALUNO-56    0.444444       -1.0                     0      1.0
# ALUNO-56    5.500000       -1.0                     0      0.0
# ALUNO-1248  3.711111       -1.0                     0      5.0
# ALUNO-1248  7.666667        0.0                     0      3.0
# ALUNO-1248  6.500000       -1.0                     0      4.0
#
#             bolsista_encoded       ipv corraca ponto_virada   ian     pedra  \
# nome
# ALUNO-75                   1  9.700000       R          Sim  10.0   Topázio
# ALUNO-75                   1  9.750010       R          Sim  10.0   Topázio
# ALUNO-75                   1  9.750010       R          Sim  10.0   Topázio
# ALUNO-916                  1  9.300000       R          Sim  10.0   Topázio
# ALUNO-916                  1  9.833343       R          Sim  10.0   Topázio
# ...                      ...       ...     ...          ...   ...       ...
# ALUNO-56                   0  4.500003       B          Não   5.0   Quartzo
# ALUNO-56                   0  7.200000       B          Não   5.0     Ágata
# ALUNO-1248                 1  3.791670       B          Não   5.0   Quartzo
# ALUNO-1248                 1  8.055553       B          Não  10.0  Ametista
# ALUNO-1248                 1  6.100000       B          Não   5.0     Ágata
#
#             ...  idade  sexo_encoded  fase      inde  sexo  na_fase   ano  \
# nome        ...
# ALUNO-75    ...   12.0           1.0     4  9.108000     F        0  2021
# ALUNO-75    ...   13.0           1.0     5  9.441522     F        0  2022
# ALUNO-75    ...   11.0           1.0     3  9.687504     F        0  2020
# ALUNO-916   ...   14.0           1.0     4  8.866000     F        1  2021
# ALUNO-916   ...   13.0           1.0     3  8.507710     F        1  2020
# ...         ...    ...           ...   ...       ...   ...      ...   ...
# ALUNO-56    ...   18.0           0.0     7  3.036573     M        0  2022
# ALUNO-56    ...   17.0           0.0     6  6.777000     M        0  2021
# ALUNO-1248  ...   15.0           1.0     4  3.031806     F        0  2022
# ALUNO-1248  ...   13.0           1.0     3  8.442779     F        1  2020
# ALUNO-1248  ...   14.0           1.0     3  6.047000     F        0  2021
#
#                cg    cf    ct
# nome
# ALUNO-75      1.0   1.0   1.0
# ALUNO-75      1.0   1.0   1.0
# ALUNO-75      1.0   1.0   1.0
# ALUNO-916     2.0   2.0   2.0
# ALUNO-916     2.0   2.0   2.0
# ...           ...   ...   ...
# ALUNO-56    861.0  23.0  15.0
# ALUNO-56    861.0  23.0  15.0
# ALUNO-1248  862.0  76.0  16.0
# ALUNO-1248  862.0  76.0  16.0
# ALUNO-1248  862.0  76.0  16.0
#
# [1646 rows x 25 columns]

# %%
df_pooled.columns
# Out:
# Index(['ida', 'diff_fase', 'ponto_virada_encoded', 'anos_pm',
#        'bolsista_encoded', 'ipv', 'corraca', 'ponto_virada', 'ian', 'pedra',
#        'pedra_encoded', 'iaa', 'ips', 'ieg', 'ipp', 'idade', 'sexo_encoded',
#        'fase', 'inde', 'sexo', 'na_fase', 'ano'],
#       dtype='object')

# %%
df_pooled_ranking.columns
# Out:
# Index(['ida', 'diff_fase', 'ponto_virada_encoded', 'anos_pm',
#        'bolsista_encoded', 'ipv', 'corraca', 'ponto_virada', 'ian', 'pedra',
#        'pedra_encoded', 'iaa', 'ips', 'ieg', 'ipp', 'idade', 'sexo_encoded',
#        'fase', 'inde', 'sexo', 'na_fase', 'ano', 'cg', 'cf', 'ct'],
#       dtype='object')

# %%
df_pooled_ranking[df_pooled_ranking["idade"].isnull()]
# Out:
# Empty DataFrame
# Columns: [ida, diff_fase, ponto_virada_encoded, anos_pm, bolsista_encoded, ipv, corraca, ponto_virada, ian, pedra, pedra_encoded, iaa, ips, ieg, ipp, idade, sexo_encoded, fase, inde, sexo, na_fase, ano, cg, cf, ct]
# Index: []
#
# [0 rows x 25 columns]

# %%
import seaborn as sns

sns.histplot(df_pooled_ranking["idade"])
# df_pooled_ranking["idade"]
# Out:
# <Axes: xlabel='idade', ylabel='Count'>

# %%
df_pooled_ranking.groupby("sexo")["inde"].mean()
# Out:
# sexo
# F    7.159566
# M    7.186987
# Name: inde, dtype: float64

# %%
df_pooled_ranking.isnull().sum()
# Out:
# ida                     0
# diff_fase               0
# ponto_virada_encoded    0
# anos_pm                 0
# bolsista_encoded        0
# ipv                     0
# corraca                 0
# ponto_virada            0
# ian                     0
# pedra                   0
# pedra_encoded           0
# iaa                     0
# ips                     0
# ieg                     0
# ipp                     0
# idade                   0
# sexo_encoded            0
# fase                    0
# inde                    0
# sexo                    0
# na_fase                 0
# ano                     0
# cg                      0
# cf                      0
# ct                      0
# dtype: int64
